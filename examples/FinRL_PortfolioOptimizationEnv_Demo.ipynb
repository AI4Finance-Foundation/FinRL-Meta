# %% [markdown]
# # A guide to Portfolio Optimization Environment
#
# This notebook aims to provide an example of using PortfolioOptimizationEnv (or POE) to train a reinforcement learning model that learns to solve the portfolio optimization problem.
#
# In this document, we will reproduce a famous architecture called EIIE (ensemble of identical independent evaluators), introduced in the following paper:
#
# - Zhengyao Jiang, Dixing Xu, & Jinjun Liang. (2017). A Deep Reinforcement Learning Framework for the Financial Portfolio Management Problem. https://doi.org/10.48550/arXiv.1706.10059.
#
# It's advisable to read it to understand the algorithm implemented in this notebook.
#
# ### Note
# If you're using this environment, consider citing the following paper (in adittion to FinRL references):
#
# - Caio Costa, & Anna Costa (2023). POE: A General Portfolio Optimization Environment for FinRL. In *Anais do II Brazilian Workshop on Artificial Intelligence in Finance* (pp. 132–143). SBC. https://doi.org/10.5753/bwaif.2023.231144.
#
# ```
# @inproceedings{bwaif,
#  author = {Caio Costa and Anna Costa},
#  title = {POE: A General Portfolio Optimization Environment for FinRL},
#  booktitle = {Anais do II Brazilian Workshop on Artificial Intelligence in Finance},
#  location = {João Pessoa/PB},
#  year = {2023},
#  keywords = {},
#  issn = {0000-0000},
#  pages = {132--143},
#  publisher = {SBC},
#  address = {Porto Alegre, RS, Brasil},
#  doi = {10.5753/bwaif.2023.231144},
#  url = {https://sol.sbc.org.br/index.php/bwaif/article/view/24959}
# }
#
# ```

# %% [markdown]
# ## Installation and imports
#
# To run this notebook in google colab, uncomment the cells below.

# %%
## install finrl library
# !sudo apt install swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %%
## We also need to install quantstats, because the environment uses it to plot graphs
# !pip install quantstats

# %%
## Hide matplotlib warnings
# import warnings
# warnings.filterwarnings('ignore')

import logging
logging.getLogger('matplotlib.font_manager').disabled = True

# %% [markdown]
# #### Import the necessary code libraries

# %%
import copy
import gym
import torch
import random
import functools

import numpy as np
import torch.nn.functional as F

from tqdm.notebook import tqdm
from collections import deque

from torch import nn
from torch.utils.data import DataLoader
from torch.utils.data.dataset import IterableDataset
from torch.optim import AdamW

from finrl.meta.preprocessor.yahoodownloader import YahooDownloader

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# ## Fetch data
#
# In his paper, *Jiang et al* creates a portfolio composed by the top-11 cryptocurrencies based on 30-days volume. Since it's not specified when this classification was done, it's difficult to reproduce, so we will use a similar approach in the Brazillian stock market:
#
# - We select top-10 stocks from Brazillian stock market;
# - For simplicity, we disconsider stocks that have missing data for a days in period 2011-01-01 to 2019-12-31 (9 years);

# %%
# TOP_BRL = [
#     "ITUB4.SA", "BBDC4.SA", "VALE3.SA", "PETR4.SA", "ABEV3.SA",
#     "BBAS3.SA"
# ]

TOP_BRL = [
    "VALE3.SA", "PETR4.SA", "ITUB4.SA", "BBDC4.SA",
    "BBAS3.SA", "RENT3.SA", "LREN3.SA", "PRIO3.SA",
    "WEGE3.SA", "ABEV3.SA"
]

# %%
print(len(TOP_BRL))

portfolio_raw_df = YahooDownloader(start_date = '2011-01-01',
                                end_date = '2019-12-31',
                                ticker_list = TOP_BRL).fetch_data()
portfolio_raw_df
# Out:
# 10
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (22330, 8)
#              date       open       high        low      close    volume  \
# 0      2011-01-03   8.632311   8.728203   8.630313   5.540226    576145
# 1      2011-01-03  31.500000  31.799999  31.379999  13.811690   3313400
# 2      2011-01-03  11.809763  11.927362  11.724237   6.802567  10862336
# 3      2011-01-03  18.031555  18.250118  17.963253  10.668523  10014663
# 4      2011-01-03   9.264964   9.492898   9.264964   7.161459   3320493
# ...           ...        ...        ...        ...        ...       ...
# 22325  2019-12-30  30.549999  30.709999  30.150000  11.973796  22111600
# 22326  2019-12-30   6.780000   6.832000   6.570000   6.612000   8933500
# 22327  2019-12-30  47.959999  48.290001  47.299999  45.060959   2701600
# 22328  2019-12-30  53.650002  53.860001  53.200001  38.828598  11928100
# 22329  2019-12-30  17.700001  17.740000  17.330000  16.492716   5838200
#
#             tic  day
# 0      ABEV3.SA    0
# 1      BBAS3.SA    0
# 2      BBDC4.SA    0
# 3      ITUB4.SA    0
# 4      LREN3.SA    0
# ...         ...  ...
# 22325  PETR4.SA    0
# 22326  PRIO3.SA    0
# 22327  RENT3.SA    0
# 22328  VALE3.SA    0
# 22329  WEGE3.SA    0
#
# [22330 rows x 8 columns]

# %%
portfolio_raw_df.groupby("tic").count()
# Out:
#           date  open  high   low  close  volume   day
# tic
# ABEV3.SA  2233  2233  2233  2233   2233    2233  2233
# BBAS3.SA  2233  2233  2233  2233   2233    2233  2233
# BBDC4.SA  2233  2233  2233  2233   2233    2233  2233
# ITUB4.SA  2233  2233  2233  2233   2233    2233  2233
# LREN3.SA  2233  2233  2233  2233   2233    2233  2233
# PETR4.SA  2233  2233  2233  2233   2233    2233  2233
# PRIO3.SA  2233  2233  2233  2233   2233    2233  2233
# RENT3.SA  2233  2233  2233  2233   2233    2233  2233
# VALE3.SA  2233  2233  2233  2233   2233    2233  2233
# WEGE3.SA  2233  2233  2233  2233   2233    2233  2233

# %% [markdown]
# ## Portfolio Optimization Environment
#
# Since POE was not merged to FinRL yet, we add its code below.

# %%
"""From FinRL https://github.com/AI4Finance-LLC/FinRL/tree/master/finrl/env"""
import gym
import math
import matplotlib
import numpy as np
import pandas as pd
from gym import spaces
from gym.utils import seeding

matplotlib.use("Agg")
import matplotlib.pyplot as plt
from stable_baselines3.common.vec_env import DummyVecEnv
from pathlib import Path

try:
    import quantstats as qs
except ModuleNotFoundError:
    raise ModuleNotFoundError(
        """QuantStats module not found, environment can't plot results and calculate indicadors.
        This module is not installed with FinRL. Install by running one of the options:
        pip install quantstats --upgrade --no-cache-dir
        conda install -c ranaroussi quantstats
        """
        )

class PortfolioOptimizationEnv(gym.Env):
    """A portfolio allocantion environment for OpenAI gym.

    This environment simulates the interactions between an agent and the financial market
    based on data provided by a dataframe. The dataframe contains the time series of
    features defined by the user (such as closing, high and low prices) and must have
    a time and a tic column with a list of datetimes and ticker symbols respectively.
    An example of dataframe is shown below::

            date        high            low             close           tic
        0   2020-12-23  0.157414        0.127420        0.136394        ADA-USD
        1   2020-12-23  34.381519       30.074295       31.097898       BNB-USD
        2   2020-12-23  24024.490234    22802.646484    23241.345703    BTC-USD
        3   2020-12-23  0.004735        0.003640        0.003768        DOGE-USD
        4   2020-12-23  637.122803      560.364258      583.714600      ETH-USD
        ... ...         ...             ...             ...             ...

    Based on this dataframe, the environment will create an observation space that can
    be a Dict or a Box. The Box observation space is a three-dimensional array of shape
    (f, n, t), where f is the number of features, n is the number of stocks in the
    portfolio and t is the user-defined time window. If the environment is created with
    the parameter return_last_action set to True, the observation space is a Dict with
    the following keys::

        {
        "state": three-dimensional Box (f, n, t) representing the time series,
        "last_action": one-dimensional Box (n+1,) representing the portfolio weights
        }

    Note that the action space of this environment is an one-dimensional Box with size
    n + 1 because the portfolio weights must contains the weights related to all the
    stocks in the portfolio and to the remaining cash.

    Attributes:
        action_space: Action space.
        observation_space: Observation space.
        episode_length: Number of timesteps of an episode.
    """
    metadata = {"render.modes": ["human"]}

    def __init__(
        self,
        df,
        initial_amount,
        order_df=True,
        return_last_action=False,
        normalize_df="by_previous_time",
        reward_scaling=1,
        comission_fee_model="trf",
        comission_fee_pct=0,
        features=["close", "high", "low"],
        valuation_feature="close",
        time_column="date",
        time_format="%Y-%m-%d",
        tic_column="tic",
        time_window=1,
        cwd="./",
        new_gym_api=False
    ):
        """Initializes environment's instance.

        Args:
            df: Dataframe with market information over a period of time.
            initial_amount: Initial amount of cash available to be invested.
            order_df: If True input dataframe is ordered by time.
            return_last_action: If True, observations also return the last performed
                action. Note that, in that case, the observation space is a Dict.
            normalize_df: Defines the normalization method applied to input dataframe.
                Possible values are "by_previous_time", "by_fist_time_window_value",
                "by_COLUMN_NAME" (where COLUMN_NAME must be changed to a real column
                name) and a custom function. If None no normalization is done.
            reward_scaling: A scaling factor to multiply the reward function. This
                factor can help training.
            comission_fee_model: Model used to simulate comission fee. Possible values
                are "trf" (for transaction remainder factor model) and "wvm" (for weights
                vector modifier model). If None, commission fees are not considered.
            comission_fee_pct: Percentage to be used in comission fee. It must be a value
                between 0 and 1.
            features: List of features to be considered in the observation space. The
                items of the list must be names of columns of the input dataframe.
            valuation_feature: Feature to be considered in the portfolio value calculation.
            time_column: Name of the dataframe's column that contain the datetimes that
                index the dataframe.
            time_format: Formatting string of time column.
            tic_name: Name of the dataframe's column that contain ticker symbols.
            time_window: Size of time window.
            cwd: Local repository in which resulting graphs will be saved.
            new_gym_api: If True, the environment will use the new gym api standard for
                step and reset methods.
        """
        # super(StockEnv, self).__init__()
        # money = 10 , scope = 1
        self._time_window = time_window
        self._time_index = time_window - 1
        self._time_column = time_column
        self._time_format = time_format
        self._tic_column = tic_column
        self._df = df
        self._initial_amount = initial_amount
        self._return_last_action = return_last_action
        self._reward_scaling = reward_scaling
        self._comission_fee_pct = comission_fee_pct
        self._comission_fee_model = comission_fee_model
        self._features = features
        self._valuation_feature = valuation_feature
        self._cwd = Path(cwd)
        self._new_gym_api = new_gym_api

        # results file
        self._results_file = self._cwd / "results" / "rl"
        self._results_file.mkdir(parents=True, exist_ok=True)

        # price variation
        self._df_price_variation = None

        # preprocess data
        self._preprocess_data(order_df, normalize_df)

        # dims and spaces
        self._tic_list = self._df[self._tic_column].unique()
        self._stock_dim = len(self._tic_list)
        action_space = 1 + self._stock_dim

        # sort datetimes and define episode length
        self._sorted_times = sorted(set(self._df[time_column]))
        self.episode_length = len(self._sorted_times) - time_window + 1

        # define action space
        self.action_space = spaces.Box(low=0, high=1, shape=(action_space,))

        # define observation state
        if self._return_last_action:
            # if  last action must be returned, a dict observation
            # is defined
            self.observation_space = spaces.Dict({
                "state": spaces.Box(
                    low=-np.inf,
                    high=np.inf,
                    shape=(
                        len(self._features),
                        self._stock_dim,
                        self._time_window
                    )
                ),
                "last_action": spaces.Box(
                    low=0, high=1, shape=(action_space,)
                )
            })
        else:
            # if information about last action is not relevant,
            # a 3D observation space is defined
            self.observation_space = spaces.Box(
                low=-np.inf,
                high=np.inf,
                shape=(
                    len(self._features),
                    self._stock_dim,
                    self._time_window
                ),
            )

        self._reset_memory()

        self._portfolio_value = self._initial_amount
        self._terminal = False

    def step(self, actions):
        """Performs a simulation step.

        Args:
            actions: An unidimensional array containing the new portfolio
                weights.

        Note:
            If the environment was created with "return_last_action" set to
            True, the next state returned will be a Dict. If it's set to False,
            the next state will be a Box. You can check the observation state
            through the attribute "observation_space".

        Returns:
            If "new_gym_api" is set to True, the following tuple is returned:
            (state, reward, terminal, truncated, info). If it's set to False,
            the following tuple is returned: (state, reward, terminal, info).

            state: Next simulation state.
            reward: Reward related to the last performed action.
            terminal: If True, the environment is in a terminal state.
            truncated: If True, the environment has passed it's simulation
                time limit. Currently, it's always False.
            info: A dictionary containing informations about the last state.
        """
        self._terminal = self._time_index >= len(self._sorted_times) - 1

        if self._terminal:
            metrics_df = pd.DataFrame(
                {"date": self._date_memory,
                 "returns": self._portfolio_return_memory,
                 "rewards": self._portfolio_reward_memory,
                 "portfolio_values": self._asset_memory["final"]}
            )
            metrics_df.set_index("date", inplace=True)

            plt.plot(metrics_df["portfolio_values"], "r")
            plt.title("Portfolio Value Over Time")
            plt.xlabel("Time")
            plt.ylabel("Portfolio value")
            plt.savefig(self._results_file / "portfolio_value.png")
            plt.close()

            plt.plot(self._portfolio_reward_memory, "r")
            plt.title("Reward Over Time")
            plt.xlabel("Time")
            plt.ylabel("Reward")
            plt.savefig(self._results_file / "reward.png")
            plt.close()

            plt.plot(self._actions_memory)
            plt.title("Actions performed")
            plt.xlabel("Time")
            plt.ylabel("Weight")
            plt.savefig(self._results_file / "actions.png")
            plt.close()

            print("=================================")
            print("Initial portfolio value:{}".format(self._asset_memory['final'][0]))
            print("Final portfolio value: {}".format(self._portfolio_value))
            print("Final accumulative portfolio value: {}".format(self._portfolio_value / self._asset_memory['final'][0]))
            print("Maximum DrawDown: {}".format(qs.stats.max_drawdown(metrics_df["portfolio_values"])))
            print("Sharpe ratio: {}".format(qs.stats.sharpe(metrics_df["returns"])))
            print("=================================")

            qs.plots.snapshot(metrics_df["returns"], show=False, savefig=self._results_file / "portfolio_summary.png")

            if self._new_gym_api:
                return self._state, self._reward, self._terminal, False, self._info
            return self._state, self._reward, self._terminal, self._info

        else:
            # transform action to numpy array (if it's a list)
            actions = np.array(actions, dtype=np.float32)

            # if necessary, normalize weights
            if math.isclose(np.sum(actions), 1, abs_tol=1e-6) and np.min(actions) >= 0:
                weights = actions
            else:
                weights = self._softmax_normalization(actions)

            # save initial portfolio weights for this time step
            self._actions_memory.append(weights)

            # get last step final weights and portfolio_value
            last_weights = self._final_weights[-1]

            # load next state
            self._time_index += 1
            self._state, self._info = self._get_state_and_info_from_time_index(self._time_index)

            # if using weights vector modifier, we need to modify weights vector
            if self._comission_fee_model == "wvm":
                delta_weights = weights - last_weights
                delta_assets = delta_weights[1:] # disconsider
                # calculate fees considering weights modification
                fees = np.sum(np.abs(delta_assets * self._portfolio_value))
                if fees > weights[0] * self._portfolio_value:
                    weights = last_weights
                    # maybe add negative reward
                else:
                    portfolio = weights * self._portfolio_value
                    portfolio[0] -= fees
                    self._portfolio_value = np.sum(portfolio) # new portfolio value
                    weights = portfolio / self._portfolio_value # new weights
            elif self._comission_fee_model == "trf":
                last_mu = 1
                mu = 1 - 2 * self._comission_fee_pct + self._comission_fee_pct ** 2
                while abs(mu - last_mu) > 1e-10:
                    last_mu = mu
                    mu = (1 - self._comission_fee_pct * weights[0] -
                          (2 * self._comission_fee_pct - self._comission_fee_pct ** 2) *
                          np.sum(np.maximum(last_weights[1:] - mu * weights[1:], 0))) / (1 - self._comission_fee_pct * weights[0])
                self._info["trf_mu"] = mu
                self._portfolio_value = mu * self._portfolio_value

            # save initial portfolio value of this time step
            self._asset_memory["initial"].append(self._portfolio_value)

            # time passes and time variation changes the portfolio distribution
            portfolio = self._portfolio_value * (weights * self._price_variation)

            # calculate new portfolio value and weights
            self._portfolio_value = np.sum(portfolio)
            weights = portfolio / self._portfolio_value

            # save final portfolio value and weights of this time step
            self._asset_memory["final"].append(self._portfolio_value)
            self._final_weights.append(weights)

            # save date memory
            self._date_memory.append(self._info["end_time"])

            # define portfolio return
            rate_of_return = self._asset_memory["final"][-1] / self._asset_memory["final"][-2]
            portfolio_return = rate_of_return - 1
            portfolio_reward = np.log(rate_of_return)

            # save portfolio return memory
            self._portfolio_return_memory.append(portfolio_return)
            self._portfolio_reward_memory.append(portfolio_reward)

            # Define portfolio return
            self._reward = portfolio_reward
            self._reward = self._reward * self._reward_scaling

        if self._new_gym_api:
            return self._state, self._reward, self._terminal, False, self._info
        return self._state, self._reward, self._terminal, self._info

    def reset(self):
        """Resets the environment and returns it to its initial state (the
        fist date of the dataframe).

        Note:
            If the environment was created with "return_last_action" set to
            True, the initial state will be a Dict. If it's set to False,
            the initial state will be a Box. You can check the observation
            state through the attribute "observation_space".

        Returns:
            If "new_gym_api" is set to True, the following tuple is returned:
            (state, info). If it's set to False, only the initial state is
            returned.

            state: Initial state.
            info: Initial state info.
        """
        # time_index must start a little bit in the future to implement lookback
        self._time_index = self._time_window - 1
        self._reset_memory()

        self._state, self._info = self._get_state_and_info_from_time_index(self._time_index)
        self._portfolio_value = self._initial_amount
        self._terminal = False

        if self._new_gym_api:
            return self._state, self._info
        return self._state

    def _get_state_and_info_from_time_index(self, time_index):
        """Gets state and information given a time index. It also updates "data"
        attribute with information about the current simulation step.

        Args:
            time_index: An integer that represents the index of a specific datetime.
                The initial datetime of the dataframe is given by 0.

        Note:
            If the environment was created with "return_last_action" set to
            True, the returned state will be a Dict. If it's set to False,
            the returned state will be a Box. You can check the observation
            state through the attribute "observation_space".

        Returns:
            A tuple with the following form: (state, info).

            state: The state of the current time index. It can be a Box or a Dict.
            info: A dictionary with some informations about the current simulation
                step. The dict has the following keys::

                {
                "tics": List of ticker symbols,
                "start_time": Start time of current time window,
                "start_time_index": Index of start time of current time window,
                "end_time": End time of current time window,
                "end_time_index": Index of end time of current time window,
                "data": Data related to the current time window,
                "price_variation": Price variation of current time step
                }
        """
        # returns state in form (channels, tics, timesteps)
        end_time = self._sorted_times[time_index]
        start_time = self._sorted_times[time_index - (self._time_window - 1)]

        # define data to be used in this time step
        self._data = self._df[
            (self._df[self._time_column] >= start_time) &
            (self._df[self._time_column] <= end_time)
        ][[self._time_column, self._tic_column] + self._features]

        # define price variation of this time_step
        self._price_variation = self._df_price_variation[
                self._df_price_variation[self._time_column] == end_time
            ][self._valuation_feature].to_numpy()
        self._price_variation = np.insert(self._price_variation, 0, 1)

        # define state to be returned
        state = None
        for tic in self._tic_list:
            tic_data = self._data[self._data[self._tic_column] == tic]
            tic_data = tic_data[self._features].to_numpy().T
            tic_data = tic_data[..., np.newaxis]
            state = tic_data if state is None else np.append(state, tic_data, axis=2)
        state = state.transpose((0, 2, 1))
        info = {
            "tics": self._tic_list,
            "start_time": start_time,
            "start_time_index": time_index - (self._time_window - 1),
            "end_time": end_time,
            "end_time_index": time_index,
            "data": self._data,
            "price_variation": self._price_variation
        }
        return self._standardize_state(state), info

    def render(self, mode="human"):
        """Renders the environment.

        Returns:
            Observation of current simulation step.
        """
        return self._state

    def _softmax_normalization(self, actions):
        """Normalizes the action vector using softmax function.

        Returns:
            Normalized action vector (portfolio vector).
        """
        numerator = np.exp(actions)
        denominator = np.sum(np.exp(actions))
        softmax_output = numerator / denominator
        return softmax_output

    def enumerate_portfolio(self):
        """Enumerates the current porfolio by showing the ticker symbols
        of all the investments considered in the portfolio.
        """
        print("Index: 0. Tic: Cash")
        for index, tic in enumerate(self._tic_list):
            print("Index: {}. Tic: {}".format(index + 1, tic))

    def _preprocess_data(self, order, normalize):
        """Orders and normalizes the environment's dataframe.

        Args:
            order: If true, the dataframe will be ordered by ticker list
                and datetime.
            normalize: Defines the normalization method applied to the dataframe.
                Possible values are "by_previous_time", "by_fist_time_window_value",
                "by_COLUMN_NAME" (where COLUMN_NAME must be changed to a real column
                name) and a custom function. If None no normalization is done.
        """
        # order time dataframe by tic and time
        if order:
            self._df = self._df.sort_values(by=[self._tic_column, self._time_column])
        # defining price variation after ordering dataframe
        self._df_price_variation = self._temporal_variation_df()
        # apply normalization
        if normalize:
            self._normalize_dataframe(normalize)
        # transform str to datetime
        self._df[self._time_column] = pd.to_datetime(self._df[self._time_column])
        self._df_price_variation[self._time_column] = pd.to_datetime(self._df_price_variation[self._time_column])
        # transform numeric variables to float32 (compatibility with pytorch)
        self._df[self._features] = self._df[self._features].astype("float32")
        self._df_price_variation[self._features] = self._df_price_variation[self._features].astype("float32")

    def _reset_memory(self):
        """Resets the environment's memory."""
        date_time = self._sorted_times[self._time_index]
        # memorize portfolio value each step
        self._asset_memory = {
            "initial" : [self._initial_amount],
            "final" : [self._initial_amount]
        }
        # memorize portfolio return and reward each step
        self._portfolio_return_memory = [0]
        self._portfolio_reward_memory = [0]
        # initial action: all money is allocated in cash
        self._actions_memory = [np.array([1] + [0] * self._stock_dim, dtype=np.float32)]
        # memorize portfolio weights at the ending of time step
        self._final_weights = [np.array([1] + [0] * self._stock_dim, dtype=np.float32)]
        # memorize datetimes
        self._date_memory = [date_time]

    def _standardize_state(self, state):
        """Standardize the state given the observation space. If "return_last_action"
        is set to False, a three-dimensional box is returned. If it's set to True, a
        dictionary is returned. The dictionary follows the standard below::

            {
            "state": Three-dimensional box representing the current state,
            "last_action": One-dimensional box representing the last action
            }
        """
        last_action = self._actions_memory[-1]
        if self._return_last_action:
            return { "state": state, "last_action": last_action }
        else:
            return state

    def _normalize_dataframe(self, normalize):
        """"Normalizes the environment's dataframe.

        Args:
            normalize: Defines the normalization method applied to the dataframe.
                Possible values are "by_previous_time", "by_fist_time_window_value",
                "by_COLUMN_NAME" (where COLUMN_NAME must be changed to a real column
                name) and a custom function. If None no normalization is done.

        Note:
            If a custom function is used in the normalization, it must have an
            argument representing the environment's dataframe.
        """
        if type(normalize) == str:
            if normalize == "by_fist_time_window_value":
                print("Normalizing {} by first time window value...".format(self._features))
                self._df = self._temporal_variation_df(self._time_window - 1)
            elif normalize == "by_previous_time":
                print("Normalizing {} by previous time...".format(self._features))
                self._df = self._temporal_variation_df()
            elif normalize.startswith("by_"):
                normalizer_column = normalize[3:]
                print("Normalizing {} by {}".format(self._features, normalizer_column))
                for column in self._features:
                    self._df[column] = self._df[column] / self._df[normalizer_column]
        elif callable(normalize):
            print("Applying custom normalization function...")
            self._df = normalize(self._df)
        else:
            print("No normalization was performed.")


    def _temporal_variation_df(self, periods=1):
        """Calculates the temporal variation dataframe. For each feature, this
        dataframe contains the rate of the current feature's value and the last
        feature's value given a period. It's used to normalize the dataframe.

        Args:
            periods: Periods (in time indexes) to calculate temporal variation.

        Returns:
            Temporal variation dataframe.
        """
        df_temporal_variation = self._df.copy()
        prev_columns = []
        for column in self._features:
            prev_column = "prev_{}".format(column)
            prev_columns.append(prev_column)
            df_temporal_variation[prev_column] = df_temporal_variation.groupby(self._tic_column)[column].shift(periods=periods)
            df_temporal_variation[column] = df_temporal_variation[column] / df_temporal_variation[prev_column]
        df_temporal_variation = df_temporal_variation.drop(columns=prev_columns).fillna(1).reset_index(drop=True)
        return df_temporal_variation

    def _seed(self, seed=None):
        """Seeds the sources of randomness of this environment to guarantee
        reproducibility.

        Args:
            seed: Seed value to be applied.

        Returns:
            Seed value applied.
        """
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self, env_number=1):
        """Generates an environment compatible with Stable Baselines 3. The
        generated environment is a vectorized version of the current one.

        Returns:
            A tuple with the generated environment and an initial observation.
        """
        e = DummyVecEnv([lambda: self] * env_number)
        obs = e.reset()
        return e, obs

# %% [markdown]
# ## Define Architecture

# %%
# Define constants
PORTFOLIO_SIZE = len(TOP_BRL)

# %% [markdown]
# #### Create the gradient policy
#
# The gradient policy below is identical to the EIIE architecture from *Jiang et al* paper.

# %%
class GradientPolicy(nn.Module):
    def __init__(self):
        """DDPG policy network initializer."""
        super().__init__()

        self.sequential = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=2, kernel_size=(1, 3)),
            nn.ReLU(),
            nn.Conv2d(in_channels=2, out_channels=20, kernel_size=(1, 48)),
            nn.ReLU()
        )

        self.final_convolution = nn.Conv2d(in_channels=21, out_channels=1, kernel_size=(1, 1))

        self.softmax = nn.Sequential(
            nn.Softmax(dim=-1)
        )

    def mu(self, observation, last_action):
        """Defines a most favorable action of this policy given input x.

        Args:
          observation: environment observation .
          last_action: Last action performed by agent.

        Returns:
          Most favorable action.
        """

        if isinstance(observation, np.ndarray):
            observation = torch.from_numpy(observation).to(device)
        if isinstance(last_action, np.ndarray):
            last_action = torch.from_numpy(last_action).to(device)

        last_stocks, cash_bias = self._process_last_action(last_action)

        output = self.sequential(observation) # shape [N, PORTFOLIO_SIZE + 1, 19, 1]
        output = torch.cat([output, last_stocks], dim=1) # shape [N, 21, PORTFOLIO_SIZE, 1]
        output = self.final_convolution(output) # shape [N, 1, PORTFOLIO_SIZE, 1]
        output = torch.cat([output, cash_bias], dim=2) # shape [N, 1, PORTFOLIO_SIZE + 1, 1]

        # output shape must be [N, features] = [1, PORTFOLIO_SIZE + 1], being N batch size (1)
        # and size the number of features (weights vector).
        output = torch.squeeze(output, 3)
        output = torch.squeeze(output, 1) # shape [N, PORTFOLIO_SIZE + 1]

        output = self.softmax(output)

        return output

    def forward(self, observation, last_action):
        """Policy network's forward propagation.

        Args:
          observation: environment observation (dictionary).
          epsilon: exploration noise to be applied.

        Returns:
          Action to be taken (numpy array).
        """
        mu = self.mu(observation, last_action)
        action = mu.cpu().detach().numpy().squeeze()
        return action

    def _process_last_action(self, last_action):
        batch_size = last_action.shape[0]
        stocks = last_action.shape[1] - 1
        last_stocks = last_action[:, 1:].reshape((batch_size, 1, stocks, 1))
        cash_bias = last_action[:, 0].reshape((batch_size, 1, 1, 1))
        return last_stocks, cash_bias

# %% [markdown]
# #### Portfolio Vector Memory
#
# The portfolio vector memory is an object that saves all the portfolio vectors generated by the policy. It's useful because the algorithm can get the last action performed, an information necessary to do forward propagation. Read *Jiang et al* article for more information.

# %%
class PVM:
    def __init__(self, capacity):
        """Initializes portfolio vector memory.

        Args:
          capacity: Max capacity of memory.
        """
        # initially, memory will have the same actions
        self.capacity = capacity
        self.reset()

    def reset(self):
        self.memory = [np.array([1] + [0] * PORTFOLIO_SIZE, dtype=np.float32)] * (self.capacity + 1)
        self.index = 0 # initial index to retrieve data

    def retrieve(self):
        last_action = self.memory[self.index]
        self.index = 0 if self.index == self.capacity else self.index + 1
        return last_action

    def add(self, action):
        self.memory[self.index] = action

# %% [markdown]
# #### ReplayBuffer and RLDataset
#
# The replay buffer implemented in this work is slightly different from the one in famous algorithms. Usually, experiences are constantly added to the replay buffer and when it's completely filled, older experiences are overwritten by new ones (deque behavior). A reinforcement learning algorithm can constantly sample experiences from the buffer to update their neural networks and, as the time passes, older experiences will be disconsidered due to the deque behavior.
#
# In this replay buffer, however, the deque behavior is still present, but when an algorithm sample a batch of experiences, all the experiences in the replay buffer are returned and it is cleared. This behavior is necessary given the policy gradient algorithm introduced by *Jiang et al*.

# %%
class ReplayBuffer:
  def __init__(self, capacity):
    """Initializes replay buffer.

    Args:
      capacity: Max capacity of buffer.
    """
    self.buffer = deque(maxlen=capacity)

  def __len__(self):
    """Represents the size of the buffer

    Returns:
      Size of the buffer.
    """
    return len(self.buffer)

  def append(self, experience):
    """Append experience to buffer. When buffer is full, it pops
       an old experience.

    Args:
      experience: experience to be saved.
    """
    self.buffer.append(experience)

  def sample(self):
    """Sample from replay buffer. All data from replay buffer is
    returned and the buffer is cleared.

    Returns:
      Sample of batch_size size.
    """
    buffer = list(self.buffer)
    self.buffer.clear()
    return buffer

# %%
class RLDataset(IterableDataset):
  def __init__(self, buffer):
    """Initializes reinforcement learning dataset.

    Args:
        buffer: replay buffer to become iterable dataset.

    Note:
        It's a subclass of pytorch's IterableDataset,
        check https://pytorch.org/docs/stable/data.html#torch.utils.data.IterableDataset
    """
    self.buffer = buffer

  def __iter__(self):
    """Iterates over RLDataset.

    Returns:
      Every experience of a sample from replay buffer.
    """
    for experience in self.buffer.sample():
        yield experience

# %% [markdown]
# #### Create Polyak average function
#
# The Polyak average function allows us to have a target function that is incrementally updated. It's useful to avoid oscillations in the final policy performance.

# %%
def polyak_average(net, target_net, tau=0.01):
  """Applies polyak average to incrementally update target net.

  Args:
    net: trained neural network.
    target_net: target neural network.
    tau: update rate.
  """
  for qp, tp in zip(net.parameters(), target_net.parameters()):
    tp.data.copy_(tau * qp.data + (1 - tau) * tp.data)

# %% [markdown]
# ### Create PG class
#
# This class implements the Policy Gradient algorithm used in *Jiang et al* paper. This algorithm is inspired by DDPG (deep deterministic policy gradient), but there are a couple of differences:
# - DDPG is an actor-critic algorithm, so it has an actor and a critic neural network. The algorithm below, however, doesn't have a critic neural network and uses the portfolio value as value function: the policy will be updated to maximize the portfolio value.
# - DDPG usually makes use of a noise parameter in the action during training to create an exploratory behavior. PG algorithm, on the other hand, has a full-exploit approach.
# - DDPG randomly samples experiences from its replay buffer. The implemented policy gradient, however, samples a sequential batch of experiences in time, to make it possible to calculate the variation of the portfolio value in the batch and use it as value function.
#
# The algorithm can be described as follows:
# 1. Initializes policy network, target policy network (if used) and replay buffer;
# 2. For each episode, do the following:
#     1. For each period of `batch_size` timesteps, do the following:
#         1. For each timestep, define an action to be performed, simulate the timestep and save the experiences in the replay buffer.
#         2. After `batch_size` timesteps are simulated, sample the replay buffer.
#         3. Update target policy network (if used).
#         4. Calculate the value function: $V = \sum\limits_{t=1}^{batch\_size} ln(\mu_{t}(W_{t} \cdot P_{t}))$, where $W_{t}$ is the action performed at timestep t, $P_{t}$ is the price variation vector at timestep t and $\mu_{t}$ is the transaction remainder factor at timestep t. Check *Jiang et al* paper for more details.
#         5. Perform gradient ascent in the policy network.
#     2. If, in the and of episode, there is sequence of remaining experiences in the replay buffer, perform steps "a" to "e" with the remaining experiences.

# %%
class PG:
    def __init__(self,
                 env,
                 batch_size=100,
                 lr=1e-3,
                 optimizer=AdamW,
                 tau=0.05):
        """Initializes Policy Gradient for portfolio optimization.

          Args:
            env: environment.
            batch_size: batch size to train neural network.
            lr: policy neural network learning rate.
            optim: Optimizer of neural network.
            tau: update rate in Polyak averaging.
        """
        # environment
        self.env = env

        # neural networks
        self.policy = GradientPolicy().to(device)
        self.target_policy = copy.deepcopy(self.policy)
        self.optimizer = optimizer(self.policy.parameters(), lr=lr)
        self.tau = tau

        # replay buffer and portfolio vector memory
        self.batch_size = batch_size
        self.buffer = ReplayBuffer(capacity=batch_size)
        self.pvm = PVM(self.env.episode_length)

        # dataset and dataloader
        dataset = RLDataset(self.buffer)
        self.dataloader = DataLoader(
            dataset=dataset,
            batch_size=batch_size,
            shuffle=False,
            pin_memory=True)

    def train(self, episodes=100):
        """Training sequence

        Args:
            episodes: Number of episodes to simulate
        """
        for i in tqdm(range(1, episodes + 1)):
            obs = self.env.reset() # observation
            self.pvm.reset() # reset portfolio vector memory
            done = False

            while not done:
                # define last_action and action and update portfolio vector memory
                last_action = self.pvm.retrieve()
                obs_batch = np.expand_dims(obs, axis=0)
                last_action_batch = np.expand_dims(last_action, axis=0)
                action = self.policy(obs_batch, last_action_batch)
                self.pvm.add(action)

                # run simulation step
                next_obs, reward, done, info = self.env.step(action)

                # add experience to replay buffer
                exp = (obs, last_action, info["price_variation"], info["trf_mu"])
                self.buffer.append(exp)

                # update policy networks
                if len(self.buffer) == self.batch_size:
                    self._gradient_ascent()

                obs = next_obs

            # gradient ascent with episode remaining buffer data
            self._gradient_ascent()



    def _gradient_ascent(self):
        # update target neural network
        polyak_average(self.policy, self.target_policy, tau=self.tau)

        # get batch data from dataloader
        obs, last_actions, price_variations, trf_mu = next(iter(self.dataloader))
        obs = obs.to(device)
        last_actions = last_actions.to(device)
        price_variations = price_variations.to(device)
        trf_mu = trf_mu.unsqueeze(1).to(device)

        # define policy loss (negative for gradient ascent)
        mu = self.policy.mu(obs, last_actions)
        policy_loss = - torch.mean(torch.log(torch.sum(mu * price_variations * trf_mu, dim=1)))

        # update policy network
        self.policy.zero_grad()
        policy_loss.backward()
        self.optimizer.step()

# %% [markdown]
# ### Train Algorithm

# %%
df_portfolio = portfolio_raw_df[["date", "tic", "close", "high", "low"]]

environment = PortfolioOptimizationEnv(
        df_portfolio,
        initial_amount=100000,
        comission_fee_pct=0.0025,
        time_window=50,
        features=["close", "high", "low"]
    )

algo = PG(environment, lr=0.0001)

algo.train(episodes=250)
# Out:
# Normalizing ['close', 'high', 'low'] by previous time...
#   0%|          | 0/250 [00:00<?, ?it/s]
# =================================
# Initial portfolio value:100000
# Final portfolio value: 362464.96875
# Final accumulative portfolio value: 3.6246496875
# Maximum DrawDown: -0.4440699399582346
# Sharpe ratio: 0.7849389829625888
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 364556.25
# Final accumulative portfolio value: 3.6455625
# Maximum DrawDown: -0.4421449793830332
# Sharpe ratio: 0.7892937802356988
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 366126.53125
# Final accumulative portfolio value: 3.6612653125
# Maximum DrawDown: -0.4403431940049325
# Sharpe ratio: 0.7927684062856463
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 367747.0
# Final accumulative portfolio value: 3.67747
# Maximum DrawDown: -0.43842459741399686
# Sharpe ratio: 0.7963865792043758
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 369505.28125
# Final accumulative portfolio value: 3.6950528125
# Maximum DrawDown: -0.4363075331518016
# Sharpe ratio: 0.8003181553749228
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 371568.25
# Final accumulative portfolio value: 3.7156825
# Maximum DrawDown: -0.4339424501626261
# Sharpe ratio: 0.8048169450195497
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 373714.90625
# Final accumulative portfolio value: 3.7371490625
# Maximum DrawDown: -0.4314305155489703
# Sharpe ratio: 0.809541365783587
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 376069.40625
# Final accumulative portfolio value: 3.7606940625
# Maximum DrawDown: -0.42857455488674345
# Sharpe ratio: 0.8147338392806049
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 378713.1875
# Final accumulative portfolio value: 3.787131875
# Maximum DrawDown: -0.42535640655366147
# Sharpe ratio: 0.8205295479935872
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 381686.0625
# Final accumulative portfolio value: 3.816860625
# Maximum DrawDown: -0.4217254372067636
# Sharpe ratio: 0.8269968963121626
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 385048.3125
# Final accumulative portfolio value: 3.850483125
# Maximum DrawDown: -0.41762118489602285
# Sharpe ratio: 0.8342204472464405
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 388642.75
# Final accumulative portfolio value: 3.8864275
# Maximum DrawDown: -0.41330517320308247
# Sharpe ratio: 0.8418679361128091
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 392620.1875
# Final accumulative portfolio value: 3.926201875
# Maximum DrawDown: -0.4084120098654047
# Sharpe ratio: 0.8502197989393124
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 397089.46875
# Final accumulative portfolio value: 3.9708946875
# Maximum DrawDown: -0.4028939892431702
# Sharpe ratio: 0.8594347031173752
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 402014.3125
# Final accumulative portfolio value: 4.020143125
# Maximum DrawDown: -0.39674380741946735
# Sharpe ratio: 0.8694503029200166
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 407539.9375
# Final accumulative portfolio value: 4.075399375
# Maximum DrawDown: -0.38990017722795967
# Sharpe ratio: 0.880407141910468
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 413645.625
# Final accumulative portfolio value: 4.13645625
# Maximum DrawDown: -0.3822130948077662
# Sharpe ratio: 0.8921755372713316
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 420251.03125
# Final accumulative portfolio value: 4.2025103125
# Maximum DrawDown: -0.3738295012713362
# Sharpe ratio: 0.9045122578491167
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 427812.625
# Final accumulative portfolio value: 4.27812625
# Maximum DrawDown: -0.364624626245019
# Sharpe ratio: 0.9179412863134807
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 435802.375
# Final accumulative portfolio value: 4.35802375
# Maximum DrawDown: -0.35514665629478603
# Sharpe ratio: 0.9315086527150404
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 444463.25
# Final accumulative portfolio value: 4.4446325
# Maximum DrawDown: -0.34874859445468465
# Sharpe ratio: 0.9453506313482509
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 453759.25
# Final accumulative portfolio value: 4.5375925
# Maximum DrawDown: -0.34190406240721427
# Sharpe ratio: 0.9591694136348754
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 463630.75
# Final accumulative portfolio value: 4.6363075
# Maximum DrawDown: -0.33705172284121643
# Sharpe ratio: 0.9726291281973038
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 473994.4375
# Final accumulative portfolio value: 4.739944375
# Maximum DrawDown: -0.3332997786016203
# Sharpe ratio: 0.9853850102049031
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 484747.6875
# Final accumulative portfolio value: 4.847476875
# Maximum DrawDown: -0.32946073885659943
# Sharpe ratio: 0.9971212778961916
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 495768.46875
# Final accumulative portfolio value: 4.9576846875
# Maximum DrawDown: -0.32558430450544373
# Sharpe ratio: 1.0075733726488154
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 506911.5
# Final accumulative portfolio value: 5.069115
# Maximum DrawDown: -0.32178049031273614
# Sharpe ratio: 1.0165503376544405
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 518045.96875
# Final accumulative portfolio value: 5.1804596875
# Maximum DrawDown: -0.31959202515486806
# Sharpe ratio: 1.0239659472026081
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 529037.8125
# Final accumulative portfolio value: 5.290378125
# Maximum DrawDown: -0.3177138106656875
# Sharpe ratio: 1.0298251517668688
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 539776.25
# Final accumulative portfolio value: 5.3977625
# Maximum DrawDown: -0.31614619983741754
# Sharpe ratio: 1.0342231752759719
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 550158.125
# Final accumulative portfolio value: 5.50158125
# Maximum DrawDown: -0.3152596648773327
# Sharpe ratio: 1.0372922850547601
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 560110.875
# Final accumulative portfolio value: 5.60110875
# Maximum DrawDown: -0.31686278845334426
# Sharpe ratio: 1.039214630116105
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 569577.625
# Final accumulative portfolio value: 5.69577625
# Maximum DrawDown: -0.3184018450850349
# Sharpe ratio: 1.0401770658012026
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 578530.875
# Final accumulative portfolio value: 5.78530875
# Maximum DrawDown: -0.3198695718793094
# Sharpe ratio: 1.0403678014024793
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 586734.375
# Final accumulative portfolio value: 5.86734375
# Maximum DrawDown: -0.3212525524282982
# Sharpe ratio: 1.040037293855191
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 593537.25
# Final accumulative portfolio value: 5.9353725
# Maximum DrawDown: -0.32256050581149587
# Sharpe ratio: 1.03851675294753
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 602113.5
# Final accumulative portfolio value: 6.021135
# Maximum DrawDown: -0.32381841613478624
# Sharpe ratio: 1.0377830980952354
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 609109.375
# Final accumulative portfolio value: 6.09109375
# Maximum DrawDown: -0.32498218043032046
# Sharpe ratio: 1.0363467665928663
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 615488.75
# Final accumulative portfolio value: 6.1548875
# Maximum DrawDown: -0.3260702444567304
# Sharpe ratio: 1.0347145180207413
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 621417.1875
# Final accumulative portfolio value: 6.214171875
# Maximum DrawDown: -0.32708856828747457
# Sharpe ratio: 1.0329857939444127
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 626912.375
# Final accumulative portfolio value: 6.26912375
# Maximum DrawDown: -0.3280420325330159
# Sharpe ratio: 1.0311952792031993
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 632022.5
# Final accumulative portfolio value: 6.320225
# Maximum DrawDown: -0.328933885838145
# Sharpe ratio: 1.0293967732094198
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 636766.125
# Final accumulative portfolio value: 6.36766125
# Maximum DrawDown: -0.32976915361136894
# Sharpe ratio: 1.0276073778678674
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 641172.125
# Final accumulative portfolio value: 6.41172125
# Maximum DrawDown: -0.33054858218908423
# Sharpe ratio: 1.025846104229008
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 645266.25
# Final accumulative portfolio value: 6.4526625
# Maximum DrawDown: -0.33128110772079955
# Sharpe ratio: 1.0241258829491633
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 649076.625
# Final accumulative portfolio value: 6.49076625
# Maximum DrawDown: -0.33196435820531633
# Sharpe ratio: 1.0224599850428642
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 652632.875
# Final accumulative portfolio value: 6.52632875
# Maximum DrawDown: -0.3326048947687035
# Sharpe ratio: 1.0208582740758676
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 655936.1875
# Final accumulative portfolio value: 6.559361875
# Maximum DrawDown: -0.3332077698385556
# Sharpe ratio: 1.0193078372011823
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 659024.25
# Final accumulative portfolio value: 6.5902425
# Maximum DrawDown: -0.33377124340787023
# Sharpe ratio: 1.0178253262846457
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 661911.875
# Final accumulative portfolio value: 6.61911875
# Maximum DrawDown: -0.3343031707697882
# Sharpe ratio: 1.0164087967957887
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 664612.4375
# Final accumulative portfolio value: 6.646124375
# Maximum DrawDown: -0.3348017714173065
# Sharpe ratio: 1.0150527535641007
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 667142.875
# Final accumulative portfolio value: 6.67142875
# Maximum DrawDown: -0.3352713350475557
# Sharpe ratio: 1.0137592740345112
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 669510.6875
# Final accumulative portfolio value: 6.695106875
# Maximum DrawDown: -0.3357148016304211
# Sharpe ratio: 1.0125205396309844
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 671736.5
# Final accumulative portfolio value: 6.717365
# Maximum DrawDown: -0.33613136599366855
# Sharpe ratio: 1.0113418333997095
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 673829.125
# Final accumulative portfolio value: 6.73829125
# Maximum DrawDown: -0.33652585447448036
# Sharpe ratio: 1.0102186943480873
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 675794.0
# Final accumulative portfolio value: 6.75794
# Maximum DrawDown: -0.33689919683035785
# Sharpe ratio: 1.0091457012707077
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 677649.0
# Final accumulative portfolio value: 6.77649
# Maximum DrawDown: -0.33725085951075673
# Sharpe ratio: 1.0081250117966885
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 679381.875
# Final accumulative portfolio value: 6.79381875
# Maximum DrawDown: -0.33758574514980777
# Sharpe ratio: 1.0071478154467604
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 681024.25
# Final accumulative portfolio value: 6.8102425
# Maximum DrawDown: -0.3379025327346339
# Sharpe ratio: 1.0062206528854436
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 682604.5
# Final accumulative portfolio value: 6.826045
# Maximum DrawDown: -0.338203539621708
# Sharpe ratio: 1.0053325449617108
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 684084.9375
# Final accumulative portfolio value: 6.840849375
# Maximum DrawDown: -0.3384875241780638
# Sharpe ratio: 1.0044910040719324
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 685476.8125
# Final accumulative portfolio value: 6.854768125
# Maximum DrawDown: -0.33875948611595474
# Sharpe ratio: 1.0036784467909572
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 686802.375
# Final accumulative portfolio value: 6.86802375
# Maximum DrawDown: -0.3390179587255129
# Sharpe ratio: 1.002909144593507
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 688060.5625
# Final accumulative portfolio value: 6.880605625
# Maximum DrawDown: -0.33926306888178415
# Sharpe ratio: 1.0021724955390743
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 689253.5
# Final accumulative portfolio value: 6.892535
# Maximum DrawDown: -0.33949615323855675
# Sharpe ratio: 1.001469699035157
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 690382.5
# Final accumulative portfolio value: 6.903825
# Maximum DrawDown: -0.3397189303526271
# Sharpe ratio: 1.0007943234560595
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 691450.0625
# Final accumulative portfolio value: 6.914500625
# Maximum DrawDown: -0.33993210378500793
# Sharpe ratio: 1.000151888319893
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 692446.4375
# Final accumulative portfolio value: 6.924464375
# Maximum DrawDown: -0.34013523030372217
# Sharpe ratio: 0.999522993716491
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 693470.0625
# Final accumulative portfolio value: 6.934700625
# Maximum DrawDown: -0.34033015085634
# Sharpe ratio: 0.9989341981226815
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 694410.75
# Final accumulative portfolio value: 6.9441075
# Maximum DrawDown: -0.3405156390554174
# Sharpe ratio: 0.9983718663029133
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 695304.0625
# Final accumulative portfolio value: 6.953040625
# Maximum DrawDown: -0.3406937802414377
# Sharpe ratio: 0.9978303411167453
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 696151.375
# Final accumulative portfolio value: 6.96151375
# Maximum DrawDown: -0.34086403897583273
# Sharpe ratio: 0.9973070350705329
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 696965.875
# Final accumulative portfolio value: 6.96965875
# Maximum DrawDown: -0.3410260431845882
# Sharpe ratio: 0.996808303073251
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 697739.5625
# Final accumulative portfolio value: 6.977395625
# Maximum DrawDown: -0.3411832757268053
# Sharpe ratio: 0.9963287774600379
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 698477.1875
# Final accumulative portfolio value: 6.984771875
# Maximum DrawDown: -0.34133232902811317
# Sharpe ratio: 0.9958633601574819
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 699197.9375
# Final accumulative portfolio value: 6.991979375
# Maximum DrawDown: -0.3414770411732836
# Sharpe ratio: 0.9954165308060747
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 699887.3125
# Final accumulative portfolio value: 6.998873125
# Maximum DrawDown: -0.34161493635938467
# Sharpe ratio: 0.9949923305245214
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 700542.5
# Final accumulative portfolio value: 7.005425
# Maximum DrawDown: -0.34174769589835563
# Sharpe ratio: 0.9945824310605627
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 701168.875
# Final accumulative portfolio value: 7.01168875
# Maximum DrawDown: -0.34187487577616626
# Sharpe ratio: 0.9941844402830072
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 701769.9375
# Final accumulative portfolio value: 7.017699375
# Maximum DrawDown: -0.34199659499303825
# Sharpe ratio: 0.9938092221223062
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 702336.9375
# Final accumulative portfolio value: 7.023369375
# Maximum DrawDown: -0.34211522099902913
# Sharpe ratio: 0.9934349352558047
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 702904.8125
# Final accumulative portfolio value: 7.029048125
# Maximum DrawDown: -0.342229663308559
# Sharpe ratio: 0.9930800339446364
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 703446.5
# Final accumulative portfolio value: 7.034465
# Maximum DrawDown: -0.3423386387875058
# Sharpe ratio: 0.9927432172733986
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 703958.375
# Final accumulative portfolio value: 7.03958375
# Maximum DrawDown: -0.34244598403952764
# Sharpe ratio: 0.9924140843169442
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 704453.3125
# Final accumulative portfolio value: 7.044533125
# Maximum DrawDown: -0.3425476536937364
# Sharpe ratio: 0.9920967063235352
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 704924.625
# Final accumulative portfolio value: 7.04924625
# Maximum DrawDown: -0.3426451852401148
# Sharpe ratio: 0.9917885164441613
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 705382.9375
# Final accumulative portfolio value: 7.053829375
# Maximum DrawDown: -0.3427396425375696
# Sharpe ratio: 0.9914934452216042
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 705836.625
# Final accumulative portfolio value: 7.05836625
# Maximum DrawDown: -0.3428317222302809
# Sharpe ratio: 0.9912075559308581
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 706258.4375
# Final accumulative portfolio value: 7.062584375
# Maximum DrawDown: -0.34292006469189384
# Sharpe ratio: 0.9909289873935048
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 706674.25
# Final accumulative portfolio value: 7.0667425
# Maximum DrawDown: -0.34300536663482273
# Sharpe ratio: 0.9906626393803671
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 707069.375
# Final accumulative portfolio value: 7.07069375
# Maximum DrawDown: -0.34308881717714923
# Sharpe ratio: 0.9904029337777601
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 707454.1875
# Final accumulative portfolio value: 7.074541875
# Maximum DrawDown: -0.3431682237827771
# Sharpe ratio: 0.9901507276998776
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 707835.8125
# Final accumulative portfolio value: 7.078358125
# Maximum DrawDown: -0.34324620239312265
# Sharpe ratio: 0.9899150328055552
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 708187.5625
# Final accumulative portfolio value: 7.081875625
# Maximum DrawDown: -0.3433204281999216
# Sharpe ratio: 0.9896778368185254
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 708538.5
# Final accumulative portfolio value: 7.085385
# Maximum DrawDown: -0.34339293129083015
# Sharpe ratio: 0.9894496774589754
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 708869.75
# Final accumulative portfolio value: 7.0886975
# Maximum DrawDown: -0.34346264170927265
# Sharpe ratio: 0.9892305048335057
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 709202.4375
# Final accumulative portfolio value: 7.092024375
# Maximum DrawDown: -0.34352981704937113
# Sharpe ratio: 0.9890204985000252
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 709508.75
# Final accumulative portfolio value: 7.0950875
# Maximum DrawDown: -0.34359562665133314
# Sharpe ratio: 0.9888089342743289
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 709821.8125
# Final accumulative portfolio value: 7.098218125
# Maximum DrawDown: -0.34366023390401135
# Sharpe ratio: 0.9886103344597338
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 710112.625
# Final accumulative portfolio value: 7.10112625
# Maximum DrawDown: -0.3437215616515308
# Sharpe ratio: 0.9884148390857628
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 710410.0625
# Final accumulative portfolio value: 7.104100625
# Maximum DrawDown: -0.3437821546606642
# Sharpe ratio: 0.9882329931933117
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 710680.625
# Final accumulative portfolio value: 7.10680625
# Maximum DrawDown: -0.3438389595078206
# Sharpe ratio: 0.9880456302163593
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 710955.625
# Final accumulative portfolio value: 7.10955625
# Maximum DrawDown: -0.34389697623762816
# Sharpe ratio: 0.9878725990394884
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 711205.125
# Final accumulative portfolio value: 7.11205125
# Maximum DrawDown: -0.3439516303511013
# Sharpe ratio: 0.9876949799871235
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 711462.4375
# Final accumulative portfolio value: 7.114624375
# Maximum DrawDown: -0.3440052850434565
# Sharpe ratio: 0.9875248435349492
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 711707.25
# Final accumulative portfolio value: 7.1170725
# Maximum DrawDown: -0.3440561854205303
# Sharpe ratio: 0.9873623632179075
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 711942.5625
# Final accumulative portfolio value: 7.119425625
# Maximum DrawDown: -0.34410686104876276
# Sharpe ratio: 0.9872032133181774
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 712174.1875
# Final accumulative portfolio value: 7.121741875
# Maximum DrawDown: -0.34415585909297985
# Sharpe ratio: 0.9870484577593832
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 712406.5
# Final accumulative portfolio value: 7.124065
# Maximum DrawDown: -0.3442024638335457
# Sharpe ratio: 0.9869044047990366
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 712624.0
# Final accumulative portfolio value: 7.12624
# Maximum DrawDown: -0.34424914534992235
# Sharpe ratio: 0.9867578053239268
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 712835.1875
# Final accumulative portfolio value: 7.128351875
# Maximum DrawDown: -0.3442937223592395
# Sharpe ratio: 0.9866160926351599
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 713039.9375
# Final accumulative portfolio value: 7.130399375
# Maximum DrawDown: -0.34433741423205777
# Sharpe ratio: 0.9864781344616057
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 713235.625
# Final accumulative portfolio value: 7.13235625
# Maximum DrawDown: -0.3443808422584351
# Sharpe ratio: 0.9863403714788042
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 713439.4375
# Final accumulative portfolio value: 7.134394375
# Maximum DrawDown: -0.3444215283392478
# Sharpe ratio: 0.986216178443283
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 713626.0625
# Final accumulative portfolio value: 7.136260625
# Maximum DrawDown: -0.3444622083079233
# Sharpe ratio: 0.9860862341282387
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 713808.5625
# Final accumulative portfolio value: 7.138085625
# Maximum DrawDown: -0.3445002861764557
# Sharpe ratio: 0.9859623496775144
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 713988.5
# Final accumulative portfolio value: 7.139885
# Maximum DrawDown: -0.3445402710136758
# Sharpe ratio: 0.9858413686159645
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 714159.625
# Final accumulative portfolio value: 7.14159625
# Maximum DrawDown: -0.3445770649687908
# Sharpe ratio: 0.9857215745219441
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 714329.8125
# Final accumulative portfolio value: 7.143298125
# Maximum DrawDown: -0.3446119094532353
# Sharpe ratio: 0.9856066890274922
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 714496.4375
# Final accumulative portfolio value: 7.144964375
# Maximum DrawDown: -0.3446492992734739
# Sharpe ratio: 0.9854975576519637
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 714663.375
# Final accumulative portfolio value: 7.14663375
# Maximum DrawDown: -0.3446831411926732
# Sharpe ratio: 0.9853896629808816
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 714819.6875
# Final accumulative portfolio value: 7.148196875
# Maximum DrawDown: -0.3447165120852792
# Sharpe ratio: 0.9852858687873948
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 714972.25
# Final accumulative portfolio value: 7.1497225
# Maximum DrawDown: -0.34474896617526374
# Sharpe ratio: 0.9851808622305454
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715119.5
# Final accumulative portfolio value: 7.151195
# Maximum DrawDown: -0.3447804350457979
# Sharpe ratio: 0.985079400128287
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715271.125
# Final accumulative portfolio value: 7.15271125
# Maximum DrawDown: -0.34481230999200996
# Sharpe ratio: 0.9849830623110104
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715410.375
# Final accumulative portfolio value: 7.15410375
# Maximum DrawDown: -0.34484226122540995
# Sharpe ratio: 0.9848870073063011
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715546.6875
# Final accumulative portfolio value: 7.155466875
# Maximum DrawDown: -0.3448724109778458
# Sharpe ratio: 0.9847914535478677
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715681.75
# Final accumulative portfolio value: 7.1568175
# Maximum DrawDown: -0.3449008237289497
# Sharpe ratio: 0.9846999084014804
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715814.75
# Final accumulative portfolio value: 7.1581475
# Maximum DrawDown: -0.34492980837778253
# Sharpe ratio: 0.9846109050364914
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715939.0
# Final accumulative portfolio value: 7.15939
# Maximum DrawDown: -0.3449574908042139
# Sharpe ratio: 0.9845218095299226
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716066.4375
# Final accumulative portfolio value: 7.160664375
# Maximum DrawDown: -0.34498338218587665
# Sharpe ratio: 0.9844379724502367
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716185.4375
# Final accumulative portfolio value: 7.161854375
# Maximum DrawDown: -0.3450118448886875
# Sharpe ratio: 0.9843523855649441
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716307.1875
# Final accumulative portfolio value: 7.163071875
# Maximum DrawDown: -0.3450368377891476
# Sharpe ratio: 0.9842723143670793
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716422.0625
# Final accumulative portfolio value: 7.164220625
# Maximum DrawDown: -0.3450615086599892
# Sharpe ratio: 0.9841928476019227
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716539.3125
# Final accumulative portfolio value: 7.165393125
# Maximum DrawDown: -0.34508641645975835
# Sharpe ratio: 0.9841155306819653
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716647.75
# Final accumulative portfolio value: 7.1664775
# Maximum DrawDown: -0.3451106752773714
# Sharpe ratio: 0.9840396512745504
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716757.875
# Final accumulative portfolio value: 7.16757875
# Maximum DrawDown: -0.34513264521791664
# Sharpe ratio: 0.9839655870231431
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716860.3125
# Final accumulative portfolio value: 7.168603125
# Maximum DrawDown: -0.3451558588695659
# Sharpe ratio: 0.9838913706083222
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716970.75
# Final accumulative portfolio value: 7.1697075
# Maximum DrawDown: -0.34517929828344307
# Sharpe ratio: 0.9838235067707767
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717070.625
# Final accumulative portfolio value: 7.17070625
# Maximum DrawDown: -0.3452000990703452
# Sharpe ratio: 0.9837546515403213
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717168.1875
# Final accumulative portfolio value: 7.171681875
# Maximum DrawDown: -0.3452220519498682
# Sharpe ratio: 0.9836844284660423
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717261.625
# Final accumulative portfolio value: 7.17261625
# Maximum DrawDown: -0.34524336658495847
# Sharpe ratio: 0.9836175349460643
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717362.0
# Final accumulative portfolio value: 7.17362
# Maximum DrawDown: -0.3452639719347125
# Sharpe ratio: 0.983554416282771
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717452.1875
# Final accumulative portfolio value: 7.174521875
# Maximum DrawDown: -0.3452835541651331
# Sharpe ratio: 0.9834915733345692
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717545.0
# Final accumulative portfolio value: 7.17545
# Maximum DrawDown: -0.34530352112425144
# Sharpe ratio: 0.9834289931099202
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717628.0
# Final accumulative portfolio value: 7.17628
# Maximum DrawDown: -0.34532300519807013
# Sharpe ratio: 0.9833663827327175
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717723.75
# Final accumulative portfolio value: 7.1772375
# Maximum DrawDown: -0.34534073352698247
# Sharpe ratio: 0.9833106909394255
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717802.25
# Final accumulative portfolio value: 7.1780225
# Maximum DrawDown: -0.3453595416914419
# Sharpe ratio: 0.9832504866424241
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717890.9375
# Final accumulative portfolio value: 7.178909375
# Maximum DrawDown: -0.3453778921007281
# Sharpe ratio: 0.9831966323217293
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717966.4375
# Final accumulative portfolio value: 7.179664375
# Maximum DrawDown: -0.34539602390745894
# Sharpe ratio: 0.9831366597980988
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718049.875
# Final accumulative portfolio value: 7.18049875
# Maximum DrawDown: -0.3454126878426863
# Sharpe ratio: 0.9830836694957453
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718122.375
# Final accumulative portfolio value: 7.18122375
# Maximum DrawDown: -0.34542869481432703
# Sharpe ratio: 0.9830289938570808
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718205.625
# Final accumulative portfolio value: 7.18205625
# Maximum DrawDown: -0.3454458683884045
# Sharpe ratio: 0.9829788766549261
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718274.625
# Final accumulative portfolio value: 7.18274625
# Maximum DrawDown: -0.34546255567369244
# Sharpe ratio: 0.9829245422955465
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718342.125
# Final accumulative portfolio value: 7.18342125
# Maximum DrawDown: -0.34547808085688847
# Sharpe ratio: 0.9828701763809887
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718421.5
# Final accumulative portfolio value: 7.184215
# Maximum DrawDown: -0.34549272247335305
# Sharpe ratio: 0.9828264395111578
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718492.1875
# Final accumulative portfolio value: 7.184921875
# Maximum DrawDown: -0.3455090121515374
# Sharpe ratio: 0.9827784081674642
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718557.1875
# Final accumulative portfolio value: 7.185571875
# Maximum DrawDown: -0.3455237443453859
# Sharpe ratio: 0.9827290416332555
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718624.5625
# Final accumulative portfolio value: 7.186245625
# Maximum DrawDown: -0.3455389493948158
# Sharpe ratio: 0.9826823285616397
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718695.875
# Final accumulative portfolio value: 7.18695875
# Maximum DrawDown: -0.3455537993161968
# Sharpe ratio: 0.9826401499407998
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718760.8125
# Final accumulative portfolio value: 7.187608125
# Maximum DrawDown: -0.34556731427447307
# Sharpe ratio: 0.9825958228064979
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718820.9375
# Final accumulative portfolio value: 7.188209375
# Maximum DrawDown: -0.3455819336892748
# Sharpe ratio: 0.9825497104297998
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718884.5625
# Final accumulative portfolio value: 7.188845625
# Maximum DrawDown: -0.34559353042339225
# Sharpe ratio: 0.982507184979027
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718947.125
# Final accumulative portfolio value: 7.18947125
# Maximum DrawDown: -0.3456068554088324
# Sharpe ratio: 0.9824668487624663
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 719001.3125
# Final accumulative portfolio value: 7.190013125
# Maximum DrawDown: -0.345621963950425
# Sharpe ratio: 0.9824230954480029
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 719059.8125
# Final accumulative portfolio value: 7.190598125
# Maximum DrawDown: -0.3456341069233855
# Sharpe ratio: 0.9823828568760455
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 719120.875
# Final accumulative portfolio value: 7.19120875
# Maximum DrawDown: -0.34564695356416464
# Sharpe ratio: 0.9823450779209874
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 719173.625
# Final accumulative portfolio value: 7.19173625
# Maximum DrawDown: -0.34565874230392
# Sharpe ratio: 0.9823028752142037
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 719228.125
# Final accumulative portfolio value: 7.19228125
# Maximum DrawDown: -0.34567036028884324
# Sharpe ratio: 0.9822663189646876
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 719286.0625
# Final accumulative portfolio value: 7.192860625
# Maximum DrawDown: -0.34568192842864154
# Sharpe ratio: 0.982231339711174
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 719336.1875
# Final accumulative portfolio value: 7.193361875
# Maximum DrawDown: -0.34569358146019724
# Sharpe ratio: 0.982191088201288
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 719386.125
# Final accumulative portfolio value: 7.19386125
# Maximum DrawDown: -0.3457057669517596
# Sharpe ratio: 0.9821534955240555
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 719442.375
# Final accumulative portfolio value: 7.19442375
# Maximum DrawDown: -0.3457170638249283
# Sharpe ratio: 0.9821214097157823
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 719493.875
# Final accumulative portfolio value: 7.19493875
# Maximum DrawDown: -0.3457265737999289
# Sharpe ratio: 0.9820891307628572
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 719544.1875
# Final accumulative portfolio value: 7.195441875
# Maximum DrawDown: -0.3457370585441927
# Sharpe ratio: 0.9820547304799726
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 719591.3125
# Final accumulative portfolio value: 7.195913125
# Maximum DrawDown: -0.34574699625456584
# Sharpe ratio: 0.9820201885678461
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 719642.4375
# Final accumulative portfolio value: 7.196424375
# Maximum DrawDown: -0.345757698864106
# Sharpe ratio: 0.9819893971993857
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 719683.4375
# Final accumulative portfolio value: 7.196834375
# Maximum DrawDown: -0.34576949909501253
# Sharpe ratio: 0.9819549335781494
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 719733.75
# Final accumulative portfolio value: 7.1973375
# Maximum DrawDown: -0.34577717394046037
# Sharpe ratio: 0.9819255274061872
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 719768.125
# Final accumulative portfolio value: 7.19768125
# Maximum DrawDown: -0.34578896125221026
# Sharpe ratio: 0.9818884605959313
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 719814.4375
# Final accumulative portfolio value: 7.198144375
# Maximum DrawDown: -0.3457979036197327
# Sharpe ratio: 0.9818597539416369
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 719859.875
# Final accumulative portfolio value: 7.19859875
# Maximum DrawDown: -0.34580766509174576
# Sharpe ratio: 0.9818315821884755
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 719901.4375
# Final accumulative portfolio value: 7.199014375
# Maximum DrawDown: -0.3458165560290798
# Sharpe ratio: 0.9818010230581108
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 719947.1875
# Final accumulative portfolio value: 7.199471875
# Maximum DrawDown: -0.34582591017376196
# Sharpe ratio: 0.9817742745289676
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 719986.5
# Final accumulative portfolio value: 7.199865
# Maximum DrawDown: -0.34583625525758666
# Sharpe ratio: 0.9817449000422088
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720018.625
# Final accumulative portfolio value: 7.20018625
# Maximum DrawDown: -0.34584327167272977
# Sharpe ratio: 0.9817126825244376
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720066.125
# Final accumulative portfolio value: 7.20066125
# Maximum DrawDown: -0.34585240167854336
# Sharpe ratio: 0.9816900224154796
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720108.6875
# Final accumulative portfolio value: 7.201086875
# Maximum DrawDown: -0.3458607931038291
# Sharpe ratio: 0.9816649739245574
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720143.0625
# Final accumulative portfolio value: 7.201430625
# Maximum DrawDown: -0.3458681255460532
# Sharpe ratio: 0.9816372260099214
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720181.625
# Final accumulative portfolio value: 7.20181625
# Maximum DrawDown: -0.3458775921163728
# Sharpe ratio: 0.9816117846601646
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720214.6875
# Final accumulative portfolio value: 7.202146875
# Maximum DrawDown: -0.3458858317810065
# Sharpe ratio: 0.9815840639022113
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720252.5625
# Final accumulative portfolio value: 7.202525625
# Maximum DrawDown: -0.34589344361921526
# Sharpe ratio: 0.9815595529595171
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720285.375
# Final accumulative portfolio value: 7.20285375
# Maximum DrawDown: -0.34590107273817505
# Sharpe ratio: 0.9815344047893642
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720321.125
# Final accumulative portfolio value: 7.20321125
# Maximum DrawDown: -0.3459083840315347
# Sharpe ratio: 0.9815094832438799
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720351.6875
# Final accumulative portfolio value: 7.203516875
# Maximum DrawDown: -0.34591641434213427
# Sharpe ratio: 0.9814840954634313
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720391.8125
# Final accumulative portfolio value: 7.203918125
# Maximum DrawDown: -0.3459226594584702
# Sharpe ratio: 0.9814649636707177
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720421.9375
# Final accumulative portfolio value: 7.204219375
# Maximum DrawDown: -0.34593250350428295
# Sharpe ratio: 0.9814406170850936
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720457.8125
# Final accumulative portfolio value: 7.204578125
# Maximum DrawDown: -0.3459377762752084
# Sharpe ratio: 0.9814189576373007
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720481.6875
# Final accumulative portfolio value: 7.204816875
# Maximum DrawDown: -0.34594546451287966
# Sharpe ratio: 0.9813930345014876
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720513.4375
# Final accumulative portfolio value: 7.205134375
# Maximum DrawDown: -0.3459510719269151
# Sharpe ratio: 0.9813700733513274
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720551.8125
# Final accumulative portfolio value: 7.205518125
# Maximum DrawDown: -0.3459584346809894
# Sharpe ratio: 0.9813536196601913
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720572.125
# Final accumulative portfolio value: 7.20572125
# Maximum DrawDown: -0.3459662088619334
# Sharpe ratio: 0.9813272023540194
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720609.25
# Final accumulative portfolio value: 7.2060925
# Maximum DrawDown: -0.3459726824644611
# Sharpe ratio: 0.9813099983265493
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720638.25
# Final accumulative portfolio value: 7.2063825
# Maximum DrawDown: -0.3459794173612988
# Sharpe ratio: 0.9812900293646954
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720667.5
# Final accumulative portfolio value: 7.206675
# Maximum DrawDown: -0.34598632015396247
# Sharpe ratio: 0.981269032828
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720695.8125
# Final accumulative portfolio value: 7.206958125
# Maximum DrawDown: -0.3459914306402997
# Sharpe ratio: 0.98124984532046
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720727.375
# Final accumulative portfolio value: 7.20727375
# Maximum DrawDown: -0.3459977794700315
# Sharpe ratio: 0.9812332792117938
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720749.625
# Final accumulative portfolio value: 7.20749625
# Maximum DrawDown: -0.34600384647330973
# Sharpe ratio: 0.9812098650164355
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720779.1875
# Final accumulative portfolio value: 7.207791875
# Maximum DrawDown: -0.34600994169922483
# Sharpe ratio: 0.9811933798248638
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720804.875
# Final accumulative portfolio value: 7.20804875
# Maximum DrawDown: -0.34601548405794436
# Sharpe ratio: 0.9811743816237181
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720831.5625
# Final accumulative portfolio value: 7.208315625
# Maximum DrawDown: -0.3460232568069388
# Sharpe ratio: 0.9811563622784489
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720852.75
# Final accumulative portfolio value: 7.2085275
# Maximum DrawDown: -0.3460264999873732
# Sharpe ratio: 0.9811350540794043
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720879.25
# Final accumulative portfolio value: 7.2087925
# Maximum DrawDown: -0.3460333652832338
# Sharpe ratio: 0.9811189903808402
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720902.5
# Final accumulative portfolio value: 7.209025
# Maximum DrawDown: -0.34603784611151023
# Sharpe ratio: 0.981100925842575
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720927.0625
# Final accumulative portfolio value: 7.209270625
# Maximum DrawDown: -0.34604312105741153
# Sharpe ratio: 0.9810839128899894
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720953.5625
# Final accumulative portfolio value: 7.209535625
# Maximum DrawDown: -0.3460487325305742
# Sharpe ratio: 0.9810680195459728
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720976.6875
# Final accumulative portfolio value: 7.209766875
# Maximum DrawDown: -0.346053412888252
# Sharpe ratio: 0.9810512405100832
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 720998.5625
# Final accumulative portfolio value: 7.209985625
# Maximum DrawDown: -0.3460595858145068
# Sharpe ratio: 0.9810338237504842
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721021.5625
# Final accumulative portfolio value: 7.210215625
# Maximum DrawDown: -0.34606322406448786
# Sharpe ratio: 0.9810178919614595
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721051.0
# Final accumulative portfolio value: 7.21051
# Maximum DrawDown: -0.34606767289207363
# Sharpe ratio: 0.9810077449749995
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721064.8125
# Final accumulative portfolio value: 7.210648125
# Maximum DrawDown: -0.3460731562654602
# Sharpe ratio: 0.980986380618284
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721083.8125
# Final accumulative portfolio value: 7.210838125
# Maximum DrawDown: -0.34607865195934795
# Sharpe ratio: 0.9809698518712113
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721106.9375
# Final accumulative portfolio value: 7.211069375
# Maximum DrawDown: -0.34608324605863017
# Sharpe ratio: 0.9809559035245311
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721128.875
# Final accumulative portfolio value: 7.21128875
# Maximum DrawDown: -0.346087621881059
# Sharpe ratio: 0.9809417238801086
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721151.375
# Final accumulative portfolio value: 7.21151375
# Maximum DrawDown: -0.3460915281489244
# Sharpe ratio: 0.9809286302682558
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721171.625
# Final accumulative portfolio value: 7.21171625
# Maximum DrawDown: -0.34609656492838425
# Sharpe ratio: 0.9809136129232383
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721189.8125
# Final accumulative portfolio value: 7.211898125
# Maximum DrawDown: -0.34610142007086087
# Sharpe ratio: 0.9808987168617614
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721211.6875
# Final accumulative portfolio value: 7.212116875
# Maximum DrawDown: -0.3461054729112514
# Sharpe ratio: 0.9808850066030664
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721233.8125
# Final accumulative portfolio value: 7.212338125
# Maximum DrawDown: -0.34611027761550295
# Sharpe ratio: 0.9808737903343653
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721255.4375
# Final accumulative portfolio value: 7.212554375
# Maximum DrawDown: -0.3461141405574003
# Sharpe ratio: 0.9808610433204112
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721274.5625
# Final accumulative portfolio value: 7.212745625
# Maximum DrawDown: -0.34611915373553603
# Sharpe ratio: 0.9808483677411924
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721290.75
# Final accumulative portfolio value: 7.2129075
# Maximum DrawDown: -0.3461222302026019
# Sharpe ratio: 0.980833599635096
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721310.875
# Final accumulative portfolio value: 7.21310875
# Maximum DrawDown: -0.346126001111286
# Sharpe ratio: 0.9808221723005239
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721323.625
# Final accumulative portfolio value: 7.21323625
# Maximum DrawDown: -0.3461312432505219
# Sharpe ratio: 0.9808047389573531
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721341.9375
# Final accumulative portfolio value: 7.213419375
# Maximum DrawDown: -0.3461356627005585
# Sharpe ratio: 0.9807932072091671
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721358.375
# Final accumulative portfolio value: 7.21358375
# Maximum DrawDown: -0.3461397736318108
# Sharpe ratio: 0.9807818699801744
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721380.6875
# Final accumulative portfolio value: 7.213806875
# Maximum DrawDown: -0.34614240041715905
# Sharpe ratio: 0.980771572200678
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721387.9375
# Final accumulative portfolio value: 7.213879375
# Maximum DrawDown: -0.3461476077734461
# Sharpe ratio: 0.9807554652705315
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721409.5625
# Final accumulative portfolio value: 7.214095625
# Maximum DrawDown: -0.34615036548836753
# Sharpe ratio: 0.9807458719453043
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721430.5
# Final accumulative portfolio value: 7.214305
# Maximum DrawDown: -0.34615250655086405
# Sharpe ratio: 0.9807373326615508
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721440.5625
# Final accumulative portfolio value: 7.214405625
# Maximum DrawDown: -0.3461568293327849
# Sharpe ratio: 0.9807215624571035
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721465.875
# Final accumulative portfolio value: 7.21465875
# Maximum DrawDown: -0.3461607572467206
# Sharpe ratio: 0.9807162484323766
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721478.0
# Final accumulative portfolio value: 7.21478
# Maximum DrawDown: -0.3461634892392206
# Sharpe ratio: 0.9807018304414669
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721495.0
# Final accumulative portfolio value: 7.21495
# Maximum DrawDown: -0.34616693172515045
# Sharpe ratio: 0.980692595833264
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721503.875
# Final accumulative portfolio value: 7.21503875
# Maximum DrawDown: -0.3461703371058721
# Sharpe ratio: 0.9806787428871306
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721519.8125
# Final accumulative portfolio value: 7.215198125
# Maximum DrawDown: -0.34617465825450267
# Sharpe ratio: 0.9806676716501432
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721533.3125
# Final accumulative portfolio value: 7.215333125
# Maximum DrawDown: -0.3461778287848015
# Sharpe ratio: 0.9806575418803674
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721548.9375
# Final accumulative portfolio value: 7.215489375
# Maximum DrawDown: -0.3461805061215353
# Sharpe ratio: 0.9806484666202218
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721560.5625
# Final accumulative portfolio value: 7.215605625
# Maximum DrawDown: -0.346184888090307
# Sharpe ratio: 0.98063657845279
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 721570.75
# Final accumulative portfolio value: 7.2157075
# Maximum DrawDown: -0.34618741732590563
# Sharpe ratio: 0.9806244187051294
# =================================

# %% [markdown]
# ### Save Model

# %%
torch.save(algo.target_policy.state_dict(), "policy_EIIE.pt")

# %% [markdown]
# ## Test Model

# %% [markdown]
# ### Define test periods
# In this work, we are going to use three annual test periods: the year of 2020, 2021 and 2022. To get data from Yahoo Finance, we do just like in the training data.

# %%
portfolio_2020_raw_df = YahooDownloader(start_date = '2020-01-01',
                                end_date = '2020-12-31',
                                ticker_list = TOP_BRL).fetch_data()
portfolio_2021_raw_df = YahooDownloader(start_date = '2021-01-01',
                                end_date = '2021-12-31',
                                ticker_list = TOP_BRL).fetch_data()
portfolio_2022_raw_df = YahooDownloader(start_date = '2022-01-01',
                                end_date = '2022-12-31',
                                ticker_list = TOP_BRL).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (2480, 8)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (2470, 8)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (2500, 8)

# %%
portfolio_2020_raw_df.groupby("tic").count()
# Out:
#           date  open  high  low  close  volume  day
# tic
# ABEV3.SA   248   248   248  248    248     248  248
# BBAS3.SA   248   248   248  248    248     248  248
# BBDC4.SA   248   248   248  248    248     248  248
# ITUB4.SA   248   248   248  248    248     248  248
# LREN3.SA   248   248   248  248    248     248  248
# PETR4.SA   248   248   248  248    248     248  248
# PRIO3.SA   248   248   248  248    248     248  248
# RENT3.SA   248   248   248  248    248     248  248
# VALE3.SA   248   248   248  248    248     248  248
# WEGE3.SA   248   248   248  248    248     248  248

# %%
portfolio_2021_raw_df.groupby("tic").count()
# Out:
#           date  open  high  low  close  volume  day
# tic
# ABEV3.SA   247   247   247  247    247     247  247
# BBAS3.SA   247   247   247  247    247     247  247
# BBDC4.SA   247   247   247  247    247     247  247
# ITUB4.SA   247   247   247  247    247     247  247
# LREN3.SA   247   247   247  247    247     247  247
# PETR4.SA   247   247   247  247    247     247  247
# PRIO3.SA   247   247   247  247    247     247  247
# RENT3.SA   247   247   247  247    247     247  247
# VALE3.SA   247   247   247  247    247     247  247
# WEGE3.SA   247   247   247  247    247     247  247

# %%
portfolio_2022_raw_df.groupby("tic").count()
# Out:
#           date  open  high  low  close  volume  day
# tic
# ABEV3.SA   250   250   250  250    250     250  250
# BBAS3.SA   250   250   250  250    250     250  250
# BBDC4.SA   250   250   250  250    250     250  250
# ITUB4.SA   250   250   250  250    250     250  250
# LREN3.SA   250   250   250  250    250     250  250
# PETR4.SA   250   250   250  250    250     250  250
# PRIO3.SA   250   250   250  250    250     250  250
# RENT3.SA   250   250   250  250    250     250  250
# VALE3.SA   250   250   250  250    250     250  250
# WEGE3.SA   250   250   250  250    250     250  250

# %% [markdown]
# ### Instantiate different environments
#
# Since we have three different periods of time, we need three different environments instantiated to simulate them.

# %%
df_portfolio_2020 = portfolio_2020_raw_df[["date", "tic", "close", "high", "low"]]
df_portfolio_2021 = portfolio_2021_raw_df[["date", "tic", "close", "high", "low"]]
df_portfolio_2022 = portfolio_2022_raw_df[["date", "tic", "close", "high", "low"]]

environment_2020 = PortfolioOptimizationEnv(
    df_portfolio_2020,
    initial_amount=100000,
    comission_fee_pct=0.0025,
    time_window=50,
    features=["close", "high", "low"]
)

environment_2021 = PortfolioOptimizationEnv(
    df_portfolio_2021,
    initial_amount=100000,
    comission_fee_pct=0.0025,
    time_window=50,
    features=["close", "high", "low"]
)

environment_2022 = PortfolioOptimizationEnv(
    df_portfolio_2022,
    initial_amount=100000,
    comission_fee_pct=0.0025,
    time_window=50,
    features=["close", "high", "low"]
)
# Out:
# Normalizing ['close', 'high', 'low'] by previous time...
# Normalizing ['close', 'high', 'low'] by previous time...
# Normalizing ['close', 'high', 'low'] by previous time...

# %% [markdown]
# ### Test EIIE architecture
# Now, we can test the EIIE architecture in the three different test periods. It's important no note three things:
# - In this code, we load the saved policy even though it's not necessary just to show how to save and load your model;
# - It's important to reset the environment before an episode and to create a new PVM (portfolio vector memory) for each case
# - The neural network is expecting a batch of data, so it's necessary to create an additional dimension to the input data if it's a single item.

# %%
EIIE_results = {
    "training": environment._asset_memory["final"],
    "2020": {},
    "2021": {},
    "2022": {}
}

policy = GradientPolicy()
policy.load_state_dict(torch.load("policy_EIIE.pt"))
policy = policy.to(device)

# 2020
done = False
obs = environment_2020.reset()
pvm = PVM(environment_2020.episode_length)
while not done:
    last_action = pvm.retrieve()
    obs_batch = np.expand_dims(obs, axis=0)
    last_action_batch = np.expand_dims(last_action, axis=0)
    action = policy(obs_batch, last_action_batch)
    pvm.add(action)
    obs, _, done, _ = environment_2020.step(action)
EIIE_results["2020"]["value"] = environment_2020._asset_memory["final"]

# 2021
done = False
obs = environment_2021.reset()
pvm = PVM(environment_2021.episode_length)
while not done:
    last_action = pvm.retrieve()
    obs_batch = np.expand_dims(obs, axis=0)
    last_action_batch = np.expand_dims(last_action, axis=0)
    action = policy(obs_batch, last_action_batch)
    pvm.add(action)
    observation, _, done, _ = environment_2021.step(action)
EIIE_results["2021"]["value"] = environment_2021._asset_memory["final"]

# 2022
done = False
obs = environment_2022.reset()
pvm = PVM(environment_2022.episode_length)
while not done:
    last_action = pvm.retrieve()
    obs_batch = np.expand_dims(obs, axis=0)
    last_action_batch = np.expand_dims(last_action, axis=0)
    action = policy(obs_batch, last_action_batch)
    pvm.add(action)
    obs, _, done, _ = environment_2022.step(action)
EIIE_results["2022"]["value"] = environment_2022._asset_memory["final"]
# Out:
# =================================
# Initial portfolio value:100000
# Final portfolio value: 220187.125
# Final accumulative portfolio value: 2.20187125
# Maximum DrawDown: -0.23349312499999997
# Sharpe ratio: 2.1238486234137266
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 90766.9921875
# Final accumulative portfolio value: 0.907669921875
# Maximum DrawDown: -0.2195288626607006
# Sharpe ratio: -0.2496135935106658
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 128866.15625
# Final accumulative portfolio value: 1.2886615625
# Maximum DrawDown: -0.3541280862501227
# Sharpe ratio: 1.0671515053952774
# =================================

# %% [markdown]
# ### Test Uniform Buy and Hold
# For comparison, we will also test the performance of a uniform buy and hold strategy. In this strategy, the portfolio has no remaining cash and the same percentage of money is allocated in each asset.

# %%
UBAH_results = {
    "train": {},
    "2020": {},
    "2021": {},
    "2022": {}
}

# train period
terminated = False
environment.reset()
while not terminated:
    action = [0] + [1/PORTFOLIO_SIZE] * PORTFOLIO_SIZE
    _, _, terminated, _ = environment.step(action)
UBAH_results["train"]["value"] = environment._asset_memory["final"]

# 2020
terminated = False
environment_2020.reset()
while not terminated:
    action = [0] + [1/PORTFOLIO_SIZE] * PORTFOLIO_SIZE
    _, _, terminated, _ = environment_2020.step(action)
UBAH_results["2020"]["value"] = environment_2020._asset_memory["final"]

# 2021
terminated = False
environment_2021.reset()
while not terminated:
    action = [0] + [1/PORTFOLIO_SIZE] * PORTFOLIO_SIZE
    _, _, terminated, _ = environment_2021.step(action)
UBAH_results["2021"]["value"] = environment_2021._asset_memory["final"]

# 2022
terminated = False
environment_2022.reset()
while not terminated:
    action = [0] + [1/PORTFOLIO_SIZE] * PORTFOLIO_SIZE
    _, _, terminated, _ = environment_2022.step(action)
UBAH_results["2022"]["value"] = environment_2022._asset_memory["final"]
# Out:
# =================================
# Initial portfolio value:100000
# Final portfolio value: 404692.1875
# Final accumulative portfolio value: 4.046921875
# Maximum DrawDown: -0.4787514798864688
# Sharpe ratio: 0.7872003173493701
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 171127.265625
# Final accumulative portfolio value: 1.71127265625
# Maximum DrawDown: -0.25080187499999995
# Sharpe ratio: 1.7124527822054514
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 95734.359375
# Final accumulative portfolio value: 0.95734359375
# Maximum DrawDown: -0.1729315254612811
# Sharpe ratio: -0.15520465269467495
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 114168.515625
# Final accumulative portfolio value: 1.14168515625
# Maximum DrawDown: -0.16239857823682546
# Sharpe ratio: 0.8454503703248608
# =================================

# %% [markdown]
# ### Plot graphics

# %%
import matplotlib.pyplot as plt

plt.plot(UBAH_results["train"]["value"], label="Buy and Hold")
plt.plot(EIIE_results["training"], label="EIIE")

plt.xlabel("Days")
plt.ylabel("Portfolio Value")
plt.title("Performance in training period")
plt.legend()

plt.show()
