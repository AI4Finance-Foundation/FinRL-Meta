# %%
# %matplotlib inline

# %% [markdown]
# # Imports

# %%
import os
import pandas as pd
from collections import defaultdict

from meta import config, config_tickers
# from meta.env_portfolio_allocation.env_portfolio_yahoofinance import StockPortfolioEnv
from meta.env_portfolio_allocation.env_portfolio_yahoofinance import StockPortfolioEnv
from meta.data_processor import DataProcessor
import numpy as np
import cvxpy as cp
import seaborn as sns
import matplotlib.pyplot as plt

from agents.stablebaselines3_models import DRLAgent
from stable_baselines3 import A2C

# %%
# function from example notebooks
def data_split(df, start, end, target_date_col="time"):
    """
    split the dataset into training or testing using time
    :param data: (df) pandas dataframe, start, end
    :return: (df) pandas dataframe
    """
    start = pd.to_datetime(start)
    end = pd.to_datetime(end)
    dates = pd.to_datetime(df[target_date_col])
    data = df[(dates >= start) & (dates < end)]
    data = data.sort_values([target_date_col, "tic"], ignore_index=True)
    data.index = data[target_date_col].factorize()[0]
    return data

# %%
# example markowitz agent using info dict from environment to do optimization at each time step
class MarkowitzAgent:
    """Provides implementations for Markowitz agent (mean-variance optimization)
    Attributes
    ----------
        env: gym environment class
            user-defined class
    Methods
    -------
        prediction()
            make a prediction in a test dataset and get result history
    """

    def __init__(
            self,
            env,
            risk_aversion=10,
            annual_risk_free_rate=0.03 # disregard risk free rate since RL disregards
            ):
        super().__init__()
        self.risk_aversion = risk_aversion
        self.env = env
        # compute daily risk free rate from annual risk free rate
        # self.risk_free_rate = (1 + annual_risk_free_rate) ** (1 / 365) - 1
        # disable risk free rate for now
        self.risk_free_rate = -1

    def get_model(self, model_name, model_kwargs):
        raise NotImplementedError()

    def train_model(self, model, cwd, total_timesteps=5000):
        raise NotImplementedError()

    def act(self, state, info):
        """
        This is the core of markowitz portfolio optimization
        it maximizes the éxpected_return - risk_aversion * risk
        with expected_return = mean_returns @ portfolio_weights
        and risk = portfolio_weights.T @ cov @ portfolio_weights
        The constraints say that the weights must be positive and sum to 1

        returns the action as the weights of the portfolio
        """
        # unpack state to get covariance and means
        data = info["data"].copy()
        # from the data estimate returns and covariances
        cov = data.iloc[-1].cov_list
        mean_returns = data[
            data["time"] == data["time"].max()
        ]["ewm_returns"].to_numpy()

        # solve markowitz model with cvxpy
        # initialize model
        num_stocks = len(mean_returns)
        weights = cp.Variable(num_stocks)
        risk_free_weight = cp.Variable(1)
        # define constraints
        # constraints = [cp.sum(weights) + risk_free_weight ==
        #                1, weights >= 0, risk_free_weight >= 0]
        constraints = [cp.sum(weights) == 1,
                       weights >= 0,
                    #    risk_free_weight >= 0
                       ]
        # define objective
        portfolio_return = mean_returns @ weights # + risk_free_weight*self.risk_free_rate
        portfolio_risk = cp.quad_form(weights, cov)
        # define objective
        objective = cp.Maximize(
            portfolio_return - self.risk_aversion * portfolio_risk)
        # define problem
        problem = cp.Problem(objective, constraints)
        # solve problem
        problem.solve()
        # get weights
        weights = weights.value
        # get action. if using risk free rate then integrate it into the action
        action = weights
        # action = np.concatenate([weights, risk_free_weight.value])
        action = np.maximum(action, 0)
        action = action / np.sum(action)
        return action

    def prediction(self, environment):
        # args = Arguments(env=environment)
        # args.if_off_policy
        # args.env = environment

        # test on the testing env
        state, info = environment.reset()
        day = environment.sorted_times[environment.time_index]
        history = defaultdict(list)

        total_asset = environment.portfolio_value
        history["date"].append(day)
        history["total_assets"].append(total_asset)
        history["episode_return"].append(0)
        # episode_total_assets.append(environment.initial_amount)
        done = False
        while not done:
            action = self.act(state, info)
            state, reward, done, trunc, info = environment.step(action)
            day = environment.sorted_times[environment.time_index]


            total_asset = environment.portfolio_value
            episode_return = total_asset / environment.initial_amount
            history["date"].append(day)
            history["total_assets"].append(total_asset)
            history["episode_return"].append(episode_return)
        print("Test Finished!")
        # return episode total_assets on testing data
        print("episode_return", episode_return)
        return pd.DataFrame(history)

# %%
# some hyperparameters for finrl
start_date=config.TRAIN_START_DATE
end_date=config.TRADE_END_DATE
ticker_list=config_tickers.DOW_30_TICKER
time_interval='1D'
data_source='yahoofinance'
technical_indicator_list= config.INDICATORS
if_vix=True
hmax=100
initial_amount=1000000
transaction_cost_pct=0.001
reward_scaling=1e-4
use_cached_model = False

# %% [markdown]
# # Download and process data

# %%
dp = DataProcessor(
    data_source=data_source,
    start_date=start_date,
    end_date=end_date,
    time_interval=time_interval,
)

price_array, tech_array, turbulence_array = dp.run(
    ticker_list, technical_indicator_list, if_vix=if_vix, cache=True, select_stockstats_talib=0
)

# add covariance matrix as states
df = dp.dataframe
df = df.sort_values(['time', 'tic'], ignore_index=True)
df.index = df.time.factorize()[0]

df["pct_change"] = df.groupby("tic").close.pct_change()

cov_list = []
# look back is one year
lookback = 252
for i in range(lookback, len(df.index.unique())):
    data_lookback = df.loc[i-lookback:i, :]
    price_lookback = data_lookback.pivot_table(
        index='time', columns='tic', values='close')
    return_lookback = price_lookback.pct_change().dropna()
    covs = return_lookback.cov().values
    cov_list.append(covs)
df["mean_pct_change_lookback"] = df.rolling(lookback)["pct_change"].mean()
df["ewm_returns"] = df["pct_change"].ewm(span=50).mean()
df_cov = pd.DataFrame(
    {'time': df.time.unique()[lookback:], 'cov_list': cov_list})
df = df.merge(df_cov, on='time')
df = df.sort_values(['time', 'tic']).reset_index(drop=True)
# Out:
# yahoofinance successfully connected
# Using cached file ./cache/AXP_AMGN_AAPL_BA_CAT_CSCO_CVX_GS_HD_HON_IBM_INTC_JNJ_KO_JPM_MCD_MMM_MRK_MSFT_NKE_PG_TRV_UNH_CRM_VZ_V_WBA_WMT_DIS_DOW_yahoofinance_2014-01-01_2021-12-01_1D.pickle
# tech_indicator_list:  ['macd', 'boll_ub', 'boll_lb', 'rsi_30', 'cci_30', 'dx_30', 'close_30_sma', 'close_60_sma']
# indicator:  macd
# indicator:  boll_ub
# indicator:  boll_lb
# indicator:  rsi_30
# indicator:  cci_30
# indicator:  dx_30
# indicator:  close_30_sma
# indicator:  close_60_sma
# Succesfully add technical indicators
# [*********************100%***********************]  1 of 1 completed
#            date       open       high        low      close  adjusted_close  \
# 0    2014-01-02  14.320000  14.590000  14.000000  14.230000       14.230000
# 1    2014-01-03  14.060000  14.220000  13.570000  13.760000       13.760000
# 2    2014-01-06  13.410000  14.000000  13.220000  13.550000       13.550000
# 3    2014-01-07  12.380000  13.280000  12.160000  12.920000       12.920000
# 4    2014-01-08  13.040000  13.240000  12.860000  12.870000       12.870000
# ...         ...        ...        ...        ...        ...             ...
# 1988 2021-11-23  20.240000  20.910000  19.030001  19.379999       19.379999
# 1989 2021-11-24  19.170000  20.959999  18.520000  18.580000       18.580000
# 1990 2021-11-26  26.620001  28.990000  23.879999  28.620001       28.620001
# 1991 2021-11-29  25.309999  25.690001  21.709999  22.959999       22.959999
# 1992 2021-11-30  26.230000  28.559999  23.709999  27.190001       27.190001
#
#       volume   tic  day
# 0          0  ^VIX    3
# 1          0  ^VIX    4
# 2          0  ^VIX    0
# 3          0  ^VIX    1
# 4          0  ^VIX    2
# ...      ...   ...  ...
# 1988       0  ^VIX    1
# 1989       0  ^VIX    2
# 1990       0  ^VIX    4
# 1991       0  ^VIX    0
# 1992       0  ^VIX    1
#
# [1993 rows x 9 columns]
# Shape of DataFrame:  (1993, 9)
# Download complete! Dataset saved to ./data/vix.csv.
# Shape of DataFrame: (1993, 9)
# Clean data for ^VIX
# /home/aaron/Research/finrl_experiments/FinRL-Meta/meta/data_processors/yahoofinance.py:177: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(tmp_df)
# Data clean for ^VIX is finished.
# Data clean all finished!
# Successfully transformed into array

# %% [markdown]
# # Run markowitz model on test data

# %%
test_df = data_split(
    df,
    start=config.TEST_START_DATE,
    end=config.TEST_END_DATE
)

stock_dimension = len(test_df.tic.unique())
state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")

env_kwargs = {
    "hmax": hmax,
    "initial_amount": initial_amount,
    "transaction_cost_pct": transaction_cost_pct,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": config.INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": reward_scaling
}
e_test_gym = StockPortfolioEnv(df=test_df, **env_kwargs)
agent = MarkowitzAgent(e_test_gym)
markowitz_history_df = agent.prediction(e_test_gym)
markowitz_history_df["method"] = "markowitz"
# Out:
# Stock Dimension: 30, State Space: 30
# =================================
# begin_total_asset:1000000
# end_total_asset:1317065.746292424
# Sharpe:  1.8108090198148892
# =================================
# Test Finished!
# episode_return 1.317065746292424

# %% [markdown]
# # Train RL model and evaluate on test data

# %%
train_df = data_split(df, start=config.TRAIN_START_DATE,
                        end=config.TRAIN_END_DATE)
stock_dimension = len(train_df.tic.unique())
state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")

env_kwargs = {
    "hmax": hmax,
    "initial_amount": initial_amount,
    "transaction_cost_pct": transaction_cost_pct,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": config.INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": reward_scaling
}
# use cached model if you are iterating on evaluation code
if use_cached_model and os.path.exists("saved_models/a2c_model.pt"):
    trained_a2c = A2C.load("saved_models/a2c_model.pt")
else:
    e_train_gym = StockPortfolioEnv(df=train_df, **env_kwargs)
    agent = DRLAgent(env=e_train_gym)

    A2C_PARAMS = {
        "n_steps": 10,
        "ent_coef": 0.005,
        "learning_rate": 0.0004
    }
    model_a2c = agent.get_model(model_name="a2c", model_kwargs=A2C_PARAMS)
    trained_a2c = agent.train_model(
        model=model_a2c,
        tb_log_name='a2c',
        total_timesteps=40000
        )
    # save trained_a2c model
    trained_a2c.save("saved_models/a2c_model.pt")

# evaluate on test data
test_df = data_split(
    df,
    start=config.TEST_START_DATE,
    end=config.TEST_END_DATE
)
e_test_gym = StockPortfolioEnv(df=test_df, **env_kwargs)

df_daily_return, df_actions = DRLAgent.DRL_prediction(
    model=trained_a2c,
    environment=e_test_gym,
)
df_daily_return["method"] = "a2c"
# Out:
# Stock Dimension: 30, State Space: 30
# {'n_steps': 10, 'ent_coef': 0.005, 'learning_rate': 0.0004}
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to tensorboard_log/a2c/a2c_4
# =================================
# begin_total_asset:1000000
# end_total_asset:1306448.6670203465
# Sharpe:  2.0796516678287724
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1307639.1310502
# Sharpe:  2.0902243062155734
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1285445.4166034753
# Sharpe:  1.9961449627713799
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1319296.7307926817
# Sharpe:  2.202596064213726
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1272895.9003085298
# Sharpe:  1.9221607834792764
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1294929.4760228002
# Sharpe:  2.089197367892366
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1317139.4855363015
# Sharpe:  2.127869745726194
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1299975.4845626622
# Sharpe:  2.0500233307988585
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1283107.5427514156
# Sharpe:  1.9360925788852692
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1291912.2637559155
# Sharpe:  2.016959802018219
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 200       |
# |    iterations         | 100       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 99        |
# |    policy_loss        | 3.22e+08  |
# |    reward             | 1262596.9 |
# |    std                | 0.994     |
# |    value_loss         | 6.13e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1297263.7250919302
# Sharpe:  2.033964826927814
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1311503.3048495224
# Sharpe:  2.0783891286879093
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1314280.4424549155
# Sharpe:  2.0912863836502686
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1295394.8443514223
# Sharpe:  2.019713085345799
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1280788.8752789
# Sharpe:  1.9201738610900583
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1336005.3319564867
# Sharpe:  2.250291724410341
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1281212.2822299285
# Sharpe:  1.9220470673488763
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1321095.487120726
# Sharpe:  2.194295718552733
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1268265.0357270723
# Sharpe:  1.874092050915508
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1289165.849684951
# Sharpe:  2.022021628554289
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1274987.3540920387
# Sharpe:  1.9030338449895532
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 203       |
# |    iterations         | 200       |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 199       |
# |    policy_loss        | 2.65e+08  |
# |    reward             | 1289160.6 |
# |    std                | 0.995     |
# |    value_loss         | 5.25e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1319767.5497187471
# Sharpe:  2.141154504070242
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1277093.9624479197
# Sharpe:  1.9429275280185727
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1275669.7301096558
# Sharpe:  1.918937422425294
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1339215.5295351897
# Sharpe:  2.27743426505728
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1306261.5928573324
# Sharpe:  2.0958839421621795
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1286596.0756276348
# Sharpe:  1.953363314555157
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1304420.916805408
# Sharpe:  2.0809468394452915
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1262137.402150314
# Sharpe:  1.8442254151931854
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1254849.5144258747
# Sharpe:  1.8171943194750133
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1264757.788943613
# Sharpe:  1.8833203894556254
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1303256.4184927433
# Sharpe:  2.0524262331249576
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 202       |
# |    iterations         | 300       |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 299       |
# |    policy_loss        | 2.49e+08  |
# |    reward             | 1145949.1 |
# |    std                | 0.995     |
# |    value_loss         | 4.33e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1266728.9405313418
# Sharpe:  1.8818209504473762
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1299343.8986768776
# Sharpe:  2.0614802432755153
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1280372.1320128231
# Sharpe:  1.9320002534834275
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1262383.1520499077
# Sharpe:  1.8491788842626635
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1307219.9922985835
# Sharpe:  2.0596747235372006
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1291916.2595447137
# Sharpe:  2.0052071850050295
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1287833.8194915457
# Sharpe:  1.9689713852336732
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1263509.5362592814
# Sharpe:  1.838719071195812
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1313967.7778771343
# Sharpe:  2.0907619818487384
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1277117.6526189276
# Sharpe:  1.930226673775957
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1287393.601063561
# Sharpe:  1.9720365363551648
# =================================
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 93       |
# |    ep_rew_mean        | 1.14e+08 |
# | time/                 |          |
# |    fps                | 201      |
# |    iterations         | 400      |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -42.4    |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 399      |
# |    policy_loss        | 2.87e+08 |
# |    reward             | 953687.7 |
# |    std                | 0.995    |
# |    value_loss         | 6.1e+13  |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1335851.9317930313
# Sharpe:  2.2092681050313545
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1259136.3009578853
# Sharpe:  1.8190537820295871
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1262905.110237042
# Sharpe:  1.870820315352207
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1288119.251522601
# Sharpe:  1.9821214360604125
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1269088.9031987886
# Sharpe:  1.904598202729186
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1305895.9089860634
# Sharpe:  2.1022559086678645
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1283626.2522776427
# Sharpe:  1.9638567769114093
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1306174.4624602837
# Sharpe:  2.07065141395441
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1304659.7303646558
# Sharpe:  2.065083320790114
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1294501.471449285
# Sharpe:  2.0066783273631197
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 203       |
# |    iterations         | 500       |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 499       |
# |    policy_loss        | 2.8e+08   |
# |    reward             | 1236601.6 |
# |    std                | 0.995     |
# |    value_loss         | 5.68e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1257624.0804547695
# Sharpe:  1.8387960409382
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1282403.7150654714
# Sharpe:  1.9636110329940855
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1277353.9465232317
# Sharpe:  1.914605221279686
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1306692.943112065
# Sharpe:  2.095664549221733
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1283723.2708222016
# Sharpe:  1.9625460400094603
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1325589.9700272419
# Sharpe:  2.177901452512352
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1269800.0263361742
# Sharpe:  1.8748853875336902
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1305003.8592278683
# Sharpe:  2.077515108031553
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1285368.3890004812
# Sharpe:  1.9933218262123884
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1263937.1045953187
# Sharpe:  1.8871475153818351
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1296453.4743125658
# Sharpe:  1.9863317422616085
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 203       |
# |    iterations         | 600       |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 599       |
# |    policy_loss        | 2.79e+08  |
# |    reward             | 1262650.0 |
# |    std                | 0.996     |
# |    value_loss         | 5.02e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1306444.1284493278
# Sharpe:  2.105080391500897
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1275166.313409982
# Sharpe:  1.9322689555124013
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1278678.391618317
# Sharpe:  1.945883666996001
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1287745.926323789
# Sharpe:  2.0110993612465347
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1310980.514275843
# Sharpe:  2.126746899401349
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1262006.7715849618
# Sharpe:  1.844278893272486
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1293616.6686118508
# Sharpe:  1.9937776347884324
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1298689.0544032347
# Sharpe:  2.0453928128545806
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1284170.0884969076
# Sharpe:  1.9763433177015797
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1273975.8673251658
# Sharpe:  1.901608302188524
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1293080.833055946
# Sharpe:  1.9692660891930531
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 203       |
# |    iterations         | 700       |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 699       |
# |    policy_loss        | 2.53e+08  |
# |    reward             | 1175960.8 |
# |    std                | 0.995     |
# |    value_loss         | 4.44e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1305350.290238444
# Sharpe:  2.092551065926783
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1279610.4512576032
# Sharpe:  1.9692362838560564
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1275247.3636130237
# Sharpe:  1.905340497714614
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1302227.201979787
# Sharpe:  2.040455926675958
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1300586.2561145285
# Sharpe:  2.0558133148359987
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1290031.20545703
# Sharpe:  2.000471395841479
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1271826.8687750082
# Sharpe:  1.9117467962356882
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1283795.046594785
# Sharpe:  1.9405508469138868
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1282874.0184216963
# Sharpe:  1.9993673247550168
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1238581.2513159541
# Sharpe:  1.7048046506660486
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1277470.1401245196
# Sharpe:  1.9201657425224454
# =================================
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 93       |
# |    ep_rew_mean        | 1.13e+08 |
# | time/                 |          |
# |    fps                | 203      |
# |    iterations         | 800      |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -42.4    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 799      |
# |    policy_loss        | 3.04e+08 |
# |    reward             | 937945.9 |
# |    std                | 0.996    |
# |    value_loss         | 6.01e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1303288.3834676398
# Sharpe:  2.0869742985873017
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1296231.7815312687
# Sharpe:  2.018442101282442
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1266377.7461089706
# Sharpe:  1.8675268233368452
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1273845.8668831408
# Sharpe:  1.9220458158656695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1281117.2247352723
# Sharpe:  1.9253332130262748
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1278775.457893051
# Sharpe:  1.9158875833931077
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1269571.8180521682
# Sharpe:  1.892265322823302
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1297925.0276477668
# Sharpe:  2.0194090590577027
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1266466.2675044318
# Sharpe:  1.866648201509836
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1309065.1543248629
# Sharpe:  2.0945622579509013
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 204       |
# |    iterations         | 900       |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 899       |
# |    policy_loss        | 3.08e+08  |
# |    reward             | 1259575.4 |
# |    std                | 0.996     |
# |    value_loss         | 5.97e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1282496.6948337972
# Sharpe:  1.9424349180671876
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1272379.0656832694
# Sharpe:  1.8950366658393625
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1295871.6843321018
# Sharpe:  2.04088380569261
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1299696.496299879
# Sharpe:  2.049806594981769
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1301547.5681262764
# Sharpe:  2.0282903489462067
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1285531.6902706288
# Sharpe:  1.9705249180427362
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1311788.492351802
# Sharpe:  2.0847815752099232
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1270145.264933816
# Sharpe:  1.8576383860930084
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1280015.4236065366
# Sharpe:  1.9056937725482688
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1293179.7850064808
# Sharpe:  1.9765705543686922
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1260846.017392502
# Sharpe:  1.806009681629623
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 203       |
# |    iterations         | 1000      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 999       |
# |    policy_loss        | 2.67e+08  |
# |    reward             | 1256028.8 |
# |    std                | 0.995     |
# |    value_loss         | 4.88e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1288279.0121705148
# Sharpe:  1.9490051489382034
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1277120.72532095
# Sharpe:  1.9397634976844529
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1285145.1258165156
# Sharpe:  1.9406116836850662
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1279035.7259362706
# Sharpe:  1.9213422495032635
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1307378.1703578767
# Sharpe:  2.0901096269788924
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1293303.16316934
# Sharpe:  1.9873394563820088
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1299537.0589313342
# Sharpe:  2.0457393840766738
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1282367.6642587823
# Sharpe:  1.9478265669896695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1279441.392857954
# Sharpe:  1.9526698383899812
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1285818.2742083487
# Sharpe:  1.9380224142287412
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1275430.8234627682
# Sharpe:  1.937824349364703
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 204       |
# |    iterations         | 1100      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1099      |
# |    policy_loss        | 2.56e+08  |
# |    reward             | 1195520.1 |
# |    std                | 0.993     |
# |    value_loss         | 4.59e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1306946.1758417054
# Sharpe:  2.0633896528170217
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1308191.1205386545
# Sharpe:  2.0659509253352017
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1279086.4797153478
# Sharpe:  1.9108286869581452
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1298037.2555096848
# Sharpe:  2.024291794732597
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1285904.5899499771
# Sharpe:  1.967017169075524
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1296131.5557956086
# Sharpe:  1.9673796902916836
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1323338.3855277651
# Sharpe:  2.134451939608828
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1258067.3339586507
# Sharpe:  1.8162731098446254
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1290863.5743926503
# Sharpe:  1.9935199575944995
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1298786.3071512594
# Sharpe:  2.0384069790939483
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1300184.3767930465
# Sharpe:  2.028337924837492
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 204       |
# |    iterations         | 1200      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1199      |
# |    policy_loss        | 3.09e+08  |
# |    reward             | 1034147.3 |
# |    std                | 0.994     |
# |    value_loss         | 6.26e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1278583.3419329019
# Sharpe:  1.916092421525094
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1289606.9988216143
# Sharpe:  1.987627497103573
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1279718.4074134598
# Sharpe:  1.9298750173613097
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1280538.4804383754
# Sharpe:  1.8960931478216598
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1254015.6603414542
# Sharpe:  1.788951646958513
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1272134.16941331
# Sharpe:  1.85436251804747
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1311470.9004082768
# Sharpe:  2.103559854729787
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1304304.620556526
# Sharpe:  1.9982897648941833
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1304198.5277904968
# Sharpe:  2.044286185796149
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1274271.9053093512
# Sharpe:  1.8747458073792858
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 204       |
# |    iterations         | 1300      |
# |    time_elapsed       | 63        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1299      |
# |    policy_loss        | 2.93e+08  |
# |    reward             | 1252157.5 |
# |    std                | 0.993     |
# |    value_loss         | 5.75e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1266100.2915671277
# Sharpe:  1.8452646351816981
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1314801.1509123351
# Sharpe:  2.0605877249790217
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1256446.2382282934
# Sharpe:  1.8231390327243033
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1271261.5371870806
# Sharpe:  1.849488585694727
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1297089.6258512556
# Sharpe:  2.0372408629317236
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1286554.5689664038
# Sharpe:  1.947103987615407
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1314421.6297498664
# Sharpe:  2.1016177407870575
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1295722.5252670816
# Sharpe:  1.9798797302700213
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1295288.1367695748
# Sharpe:  2.02883269267412
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1326133.7232096875
# Sharpe:  2.1745001658032983
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1277761.8048818333
# Sharpe:  1.9124041702961134
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 204       |
# |    iterations         | 1400      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1399      |
# |    policy_loss        | 2.63e+08  |
# |    reward             | 1223831.8 |
# |    std                | 0.991     |
# |    value_loss         | 4.74e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1253263.3030467394
# Sharpe:  1.79377964548967
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1271748.6039599099
# Sharpe:  1.9095793887543686
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1310411.1787571318
# Sharpe:  2.0946806348906555
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1274138.8117308256
# Sharpe:  1.9217926832910364
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1299565.2197648603
# Sharpe:  2.0412564255997028
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1276768.6906522296
# Sharpe:  1.9258219792349658
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1284640.8316165726
# Sharpe:  1.9840364594217021
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1283528.919830087
# Sharpe:  1.9560810809401865
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1279082.549177439
# Sharpe:  1.925280340943537
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1249945.7390226151
# Sharpe:  1.7536587882147605
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1254812.5743158367
# Sharpe:  1.7833410278774833
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 204       |
# |    iterations         | 1500      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1499      |
# |    policy_loss        | 2.67e+08  |
# |    reward             | 1193217.1 |
# |    std                | 0.991     |
# |    value_loss         | 4.7e+13   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1267072.239279388
# Sharpe:  1.849995623305318
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1295132.6552267107
# Sharpe:  2.0198881882719575
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1268131.703410145
# Sharpe:  1.8648600185579916
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1254302.8372251878
# Sharpe:  1.7537482568619567
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1278985.7684005778
# Sharpe:  1.9115743856867613
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1308000.4142977125
# Sharpe:  2.0602806172932975
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1253146.7942408354
# Sharpe:  1.8050512927428455
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1299117.4286426308
# Sharpe:  2.0442569563382
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1285620.038476978
# Sharpe:  1.9943903711201048
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1270489.3730496806
# Sharpe:  1.8430355998514225
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1267497.8801742361
# Sharpe:  1.8698133144572473
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 204       |
# |    iterations         | 1600      |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1599      |
# |    policy_loss        | 2.95e+08  |
# |    reward             | 1060273.2 |
# |    std                | 0.991     |
# |    value_loss         | 5.95e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1311024.6570171576
# Sharpe:  2.107678067876903
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1279883.3012666819
# Sharpe:  1.9146697039756637
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1267735.1191437673
# Sharpe:  1.8663599374247086
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1229767.7478816297
# Sharpe:  1.6319755818659418
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1282626.1048741532
# Sharpe:  1.9419340382322907
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1271754.5116231006
# Sharpe:  1.8873419621930132
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1285364.5046355636
# Sharpe:  1.9273453284061735
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1305700.3521779217
# Sharpe:  2.0775464440625955
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1298485.6296384702
# Sharpe:  2.006639909171628
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1290995.7771366101
# Sharpe:  1.9404601910475394
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 204       |
# |    iterations         | 1700      |
# |    time_elapsed       | 83        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -42.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1699      |
# |    policy_loss        | 2.9e+08   |
# |    reward             | 1277055.1 |
# |    std                | 0.989     |
# |    value_loss         | 5.82e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1272021.400232764
# Sharpe:  1.8717999021955045
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1266083.836454403
# Sharpe:  1.8609092947537622
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1272980.1806303295
# Sharpe:  1.8824258327762726
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1272250.9845194567
# Sharpe:  1.842886539022107
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1292655.060264534
# Sharpe:  2.019688112299622
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1260959.0608897752
# Sharpe:  1.8471331484050832
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1284219.3212504843
# Sharpe:  1.962082284496303
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1272785.5564857177
# Sharpe:  1.8827920996024825
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1260976.8353359054
# Sharpe:  1.8545988418168273
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1290911.106541366
# Sharpe:  1.990693781185552
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1251102.7635042507
# Sharpe:  1.7777096976687083
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 204       |
# |    iterations         | 1800      |
# |    time_elapsed       | 88        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -42.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1799      |
# |    policy_loss        | 2.79e+08  |
# |    reward             | 1273204.9 |
# |    std                | 0.99      |
# |    value_loss         | 5e+13     |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1311478.9024490719
# Sharpe:  2.0882949373808377
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1280906.884700881
# Sharpe:  1.9360089840327361
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1265593.0824995574
# Sharpe:  1.8854626496739981
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1277961.2636188702
# Sharpe:  1.925302523130359
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1248194.3448784382
# Sharpe:  1.759470640140926
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1265385.2191370004
# Sharpe:  1.855125979180602
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1274028.4137533153
# Sharpe:  1.8668430983922601
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1279098.634075695
# Sharpe:  1.8831422492916214
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1280547.1520675565
# Sharpe:  1.948648194441464
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1269413.651827278
# Sharpe:  1.8825914640463146
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1254484.3626894667
# Sharpe:  1.7772250481120018
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 204       |
# |    iterations         | 1900      |
# |    time_elapsed       | 93        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1899      |
# |    policy_loss        | 2.7e+08   |
# |    reward             | 1240544.4 |
# |    std                | 0.991     |
# |    value_loss         | 4.82e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1298400.3067258208
# Sharpe:  2.046654296164447
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1290941.2954515119
# Sharpe:  1.9933570757227879
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1282690.6985951464
# Sharpe:  1.9556888639693777
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1243488.5536747961
# Sharpe:  1.7458149534681136
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1273003.7671241988
# Sharpe:  1.8866754663252379
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1292973.325052665
# Sharpe:  2.029335067516436
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1270918.3740377708
# Sharpe:  1.9004287292330904
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1296698.4792534048
# Sharpe:  2.012094975205021
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1288849.8076658312
# Sharpe:  1.9608696619405805
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1273012.5310290414
# Sharpe:  1.9104405959926702
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1296424.5472594849
# Sharpe:  2.0246341396589793
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 203       |
# |    iterations         | 2000      |
# |    time_elapsed       | 98        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | 0         |
# ...
# begin_total_asset:1000000
# end_total_asset:1288815.2012161175
# Sharpe:  1.9612056620873846
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1267012.087431815
# Sharpe:  1.8603382118248672
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1260515.4733741132
# Sharpe:  1.8480233362277079
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1255828.4413463892
# Sharpe:  1.8198010162308544
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 203       |
# |    iterations         | 3400      |
# |    time_elapsed       | 166       |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -42.1     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3399      |
# |    policy_loss        | 2.62e+08  |
# |    reward             | 1350402.9 |
# |    std                | 0.984     |
# |    value_loss         | 5.03e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1288484.7683160037
# Sharpe:  1.994986055066736
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1266765.7232953287
# Sharpe:  1.8481247577957445
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1277894.401077777
# Sharpe:  1.9320222876546918
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1260986.2919509641
# Sharpe:  1.831854457940794
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1274339.0314151216
# Sharpe:  1.8957433328849609
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1276038.7270334645
# Sharpe:  1.9221332921328937
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1272322.2781399102
# Sharpe:  1.8754688185726618
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1301461.594296614
# Sharpe:  2.0426220203031478
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1267985.1500204152
# Sharpe:  1.8898960816177568
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1300531.227991474
# Sharpe:  2.041978157248056
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1298817.7545925183
# Sharpe:  2.032852977696268
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 203       |
# |    iterations         | 3500      |
# |    time_elapsed       | 171       |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -42.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3499      |
# |    policy_loss        | 2.52e+08  |
# |    reward             | 1168130.1 |
# |    std                | 0.984     |
# |    value_loss         | 4.83e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1278477.0659422958
# Sharpe:  1.9343110978038658
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1277726.8657414592
# Sharpe:  1.9201743027676537
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1299253.1935428393
# Sharpe:  2.04172790014739
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1256066.215092193
# Sharpe:  1.8237081111931486
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1284770.2601909786
# Sharpe:  1.9329962647040158
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1265289.0592914498
# Sharpe:  1.8506775609797836
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1272438.3368820897
# Sharpe:  1.8993761518469066
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1253810.992259301
# Sharpe:  1.762335388646208
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1305026.758230713
# Sharpe:  2.093726179249428
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1272662.7187512068
# Sharpe:  1.8950184647318438
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1248928.9412151356
# Sharpe:  1.7738540696019647
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 203       |
# |    iterations         | 3600      |
# |    time_elapsed       | 176       |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3599      |
# |    policy_loss        | 2.85e+08  |
# |    reward             | 1046492.7 |
# |    std                | 0.983     |
# |    value_loss         | 5.75e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1291543.0085872512
# Sharpe:  1.9827887000234814
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1263183.6829253985
# Sharpe:  1.830714830182326
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1297911.9151482373
# Sharpe:  2.023208767394754
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1280042.7089777861
# Sharpe:  1.9308040015449257
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1302900.455183444
# Sharpe:  2.0658416475628925
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1288253.6565225627
# Sharpe:  1.9819397992537366
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1315893.9141247224
# Sharpe:  2.1394006339855847
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1280885.2827084067
# Sharpe:  1.9376562475365917
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1317870.0313004788
# Sharpe:  2.154234081554636
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1312503.4243432789
# Sharpe:  2.116952735311664
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 203       |
# |    iterations         | 3700      |
# |    time_elapsed       | 181       |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3699      |
# |    policy_loss        | 2.66e+08  |
# |    reward             | 1236185.6 |
# |    std                | 0.983     |
# |    value_loss         | 5.47e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1252121.0375033198
# Sharpe:  1.7587361827660957
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1245676.1453900654
# Sharpe:  1.7446527760678348
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1264054.7318292544
# Sharpe:  1.8680768592130816
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1289292.6978222118
# Sharpe:  2.0133868341699577
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1309933.300539869
# Sharpe:  2.0838305822388303
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1302551.6662682123
# Sharpe:  2.0541117415817367
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1270875.6944103502
# Sharpe:  1.9037830269378682
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1271676.8384730269
# Sharpe:  1.917807259903289
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1260710.235656858
# Sharpe:  1.838482721047598
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1259327.4169495502
# Sharpe:  1.831474540130443
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1265059.0273321595
# Sharpe:  1.87596983783856
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 203       |
# |    iterations         | 3800      |
# |    time_elapsed       | 186       |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -42.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3799      |
# |    policy_loss        | 2.61e+08  |
# |    reward             | 1344776.2 |
# |    std                | 0.985     |
# |    value_loss         | 5.19e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1292904.7328114952
# Sharpe:  2.0309052173141
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1292820.4862940218
# Sharpe:  1.998396039622546
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1255300.689114269
# Sharpe:  1.8021020392817833
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1297799.0578972527
# Sharpe:  2.029343515942544
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1274210.5637157243
# Sharpe:  1.91647436685726
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1289831.1513294855
# Sharpe:  2.0091787296600176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1274518.0348998308
# Sharpe:  1.8813194963685431
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1279416.9763617225
# Sharpe:  1.9435994923339506
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1257679.5411187143
# Sharpe:  1.858087338530323
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1283065.37088706
# Sharpe:  1.9691666060084794
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1285098.9918940782
# Sharpe:  1.9418479961412143
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 203       |
# |    iterations         | 3900      |
# |    time_elapsed       | 191       |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -42.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3899      |
# |    policy_loss        | 2.65e+08  |
# |    reward             | 1163179.4 |
# |    std                | 0.984     |
# |    value_loss         | 4.93e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1300819.9948615786
# Sharpe:  2.051598395530575
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1281928.4145968484
# Sharpe:  1.964122570520142
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1244934.5889479357
# Sharpe:  1.7819219687001329
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1291844.2665706433
# Sharpe:  1.9958889282732508
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1269614.6323298765
# Sharpe:  1.8618606181856034
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1294549.1638915148
# Sharpe:  1.9899132666425179
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1286378.30946912
# Sharpe:  1.9740223814556888
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1300414.837575342
# Sharpe:  2.0626197661122823
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1256047.8862659864
# Sharpe:  1.8277351704328637
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1256153.1692509574
# Sharpe:  1.8206441960556765
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1257423.0734421152
# Sharpe:  1.8134559507430603
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 203       |
# |    iterations         | 4000      |
# |    time_elapsed       | 196       |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -42.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3999      |
# |    policy_loss        | 2.92e+08  |
# |    reward             | 1069909.9 |
# |    std                | 0.985     |
# |    value_loss         | 5.8e+13   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1308442.3764505207
# Sharpe:  1.682439864404891
# =================================
# hit end!

# %%
df_daily_return["total_assets"] = (1+df_daily_return["daily_return"]).cumprod() * e_test_gym.initial_amount

# %% [markdown]
# # Plot returns comparison

# %%
cols = ["date", "total_assets", "method"]
df_to_plot = pd.concat([df_daily_return[cols], markowitz_history_df[cols]])

sns.lineplot(
    x="date",
    y="total_assets",
    hue="method",
    data=df_to_plot
    )
plt.title("return comparison")
plt.show()

# %% [markdown]
# # Get returns tearsheet using pyfolio
# note that this requires a modified version of pyfolio which has bugs, ignore the download_data error as long as you get
# "yahoofinance successfully connected"

# %%
# code for analyzing returns using pyfolio, creating a tear sheet
import pyfolio as pf

# %%
try:
    _ = dp.processor.download_data(["^GSPC"], save_path="./data/sp500.csv")
except:
    pass
# Out:
# [*********************100%***********************]  1 of 1 completed
#            date         open         high          low        close  \
# 0    2014-01-02  1845.859985  1845.859985  1827.739990  1831.979980
# 1    2014-01-03  1833.209961  1838.239990  1829.130005  1831.369995
# 2    2014-01-06  1832.310059  1837.160034  1823.729980  1826.770020
# 3    2014-01-07  1828.709961  1840.099976  1828.709961  1837.880005
# 4    2014-01-08  1837.900024  1840.020020  1831.400024  1837.489990
# ...         ...          ...          ...          ...          ...
# 1988 2021-11-23  4678.479980  4699.390137  4652.660156  4690.700195
# 1989 2021-11-24  4675.779785  4702.870117  4659.890137  4701.459961
# 1990 2021-11-26  4664.629883  4664.629883  4585.430176  4594.620117
# 1991 2021-11-29  4628.750000  4672.950195  4625.259766  4655.270020
# 1992 2021-11-30  4640.250000  4646.020020  4560.000000  4567.000000
#
#       adjusted_close      volume    tic  day
# 0        1831.979980  3080600000  ^GSPC    3
# 1        1831.369995  2774270000  ^GSPC    4
# 2        1826.770020  3294850000  ^GSPC    0
# 3        1837.880005  3511750000  ^GSPC    1
# 4        1837.489990  3652140000  ^GSPC    2
# ...              ...         ...    ...  ...
# 1988     4690.700195  4277590000  ^GSPC    1
# 1989     4701.459961  3418430000  ^GSPC    2
# 1990     4594.620117  3517700000  ^GSPC    4
# 1991     4655.270020  4336410000  ^GSPC    0
# 1992     4567.000000  6625990000  ^GSPC    1
#
# [1993 rows x 9 columns]
# Shape of DataFrame:  (1993, 9)
# Download complete! Dataset saved to ./data/sp500.csv.
# Shape of DataFrame: (1993, 9)

# %%
sp500_data = pd.read_csv("./data/sp500.csv")

# %%
sp500_data = sp500_data.set_index(pd.to_datetime(sp500_data["date"]))
sp500_data.index = sp500_data.index.tz_localize('America/New_York')
sp500_data['pct_change'] = sp500_data.close.pct_change()
sp500_data = sp500_data.dropna()
# sp500_data.index = sp500_data.index.to_pydatetime()

# %% [markdown]
# # plot quantstats metrics
# ideally we want to fix quantstats or compute the metrics ourselves, but this is just an example
#
# quantstats is broken for me requiring the try, catch

# %%
# quantstats tear sheet
for method_name in df_to_plot.method.unique():
    print(f"{method_name} tear sheet")
    port_returns = df_to_plot[df_to_plot["method"] == method_name].drop_duplicates("date").set_index("date")["total_assets"]
    port_returns.index = port_returns.index.tz_localize('America/New_York')

    try:
        pf.create_returns_tear_sheet(port_returns.pct_change().dropna(), benchmark_rets=sp500_data["pct_change"])
    except:
        pass
# Out:
# a2c tear sheet
# Entire data start date: 2020-08-04
# Entire data end date: 2021-09-30
# Backtest months: 13
# /home/aaron/miniconda3/envs/finrl/lib/python3.8/site-packages/pyfolio/timeseries.py:718: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   stats = pd.Series()
# /home/aaron/miniconda3/envs/finrl/lib/python3.8/site-packages/pyfolio/plotting.py:693: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for stat, value in perf_stats[column].iteritems():
#                     Backtest
# Annual return          26.0%
# Cumulative returns     30.8%
# Annual volatility      14.3%
# Sharpe ratio            1.69
# Calmar ratio            3.09
# Stability               0.89
# Max drawdown           -8.4%
# Omega ratio             1.33
# Sortino ratio           2.56
# Skew                    0.02
# Kurtosis                2.22
# Tail ratio              1.13
# Daily value at risk    -1.7%
# Alpha                   0.04
# Beta                    0.85
# markowitz tear sheet
# Entire data start date: 2020-08-04
# Entire data end date: 2021-09-30
# Backtest months: 13
# /home/aaron/miniconda3/envs/finrl/lib/python3.8/site-packages/pyfolio/timeseries.py:718: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   stats = pd.Series()
# /home/aaron/miniconda3/envs/finrl/lib/python3.8/site-packages/pyfolio/plotting.py:693: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for stat, value in perf_stats[column].iteritems():
#                     Backtest
# Annual return          26.7%
# Cumulative returns     31.7%
# Annual volatility      13.6%
# Sharpe ratio            1.81
# Calmar ratio            4.62
# Stability               0.82
# Max drawdown           -5.8%
# Omega ratio             1.36
# Sortino ratio           2.93
# Skew                    0.54
# Kurtosis                3.09
# Tail ratio              1.17
# Daily value at risk    -1.6%
# Alpha                   0.11
# Beta                    0.58
