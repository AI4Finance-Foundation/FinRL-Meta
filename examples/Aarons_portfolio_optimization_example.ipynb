# %%
# %matplotlib inline

# %% [markdown]
# ## Aaron's installation cheatsheet (for linux)
# ```
# conda create -n finrl --no-default-packages
# conda activate finrl
# git clone git@github.com:AI4Finance-Foundation/FinRL-Meta.git
# cd FinRL-Meta
# mamba install -y python==3.8 swig
# mamba install -y ta-lib pyfolio -c conda-forge
# mamba install -y pytorch -c pytorch
# mamba install tensorboard
# pip install -e .
# ```
#
# The last line allows you to edit the python files without having to redo the pip install

# %% [markdown]
# # Imports

# %%
import os
import pandas as pd
from collections import defaultdict

from meta import config, config_tickers
# from meta.env_portfolio_allocation.env_portfolio_yahoofinance import StockPortfolioEnv
from meta.env_portfolio_allocation.env_portfolio_yahoofinance import StockPortfolioEnv
from meta.data_processor import DataProcessor
import numpy as np
import cvxpy as cp
import seaborn as sns
import matplotlib.pyplot as plt

from agents.stablebaselines3_models import DRLAgent
from stable_baselines3 import A2C

# %%
# function from example notebooks
def data_split(df, start, end, target_date_col="time"):
    """
    split the dataset into training or testing using time
    :param data: (df) pandas dataframe, start, end
    :return: (df) pandas dataframe
    """
    start = pd.to_datetime(start)
    end = pd.to_datetime(end)
    dates = pd.to_datetime(df[target_date_col])
    data = df[(dates >= start) & (dates < end)]
    data = data.sort_values([target_date_col, "tic"], ignore_index=True)
    data.index = data[target_date_col].factorize()[0]
    return data

# %%
# example markowitz agent using info dict from environment to do optimization at each time step
class MarkowitzAgent:
    """Provides implementations for Markowitz agent (mean-variance optimization)
    Attributes
    ----------
        env: gym environment class
            user-defined class
    Methods
    -------
        prediction()
            make a prediction in a test dataset and get result history
    """

    def __init__(
            self,
            env,
            risk_aversion=10,
            annual_risk_free_rate=0.03 # disregard risk free rate since RL disregards
            ):
        super().__init__()
        self.risk_aversion = risk_aversion
        self.env = env
        # compute daily risk free rate from annual risk free rate
        # self.risk_free_rate = (1 + annual_risk_free_rate) ** (1 / 365) - 1
        # disable risk free rate for now
        self.risk_free_rate = -1

    def get_model(self, model_name, model_kwargs):
        raise NotImplementedError()

    def train_model(self, model, cwd, total_timesteps=5000):
        raise NotImplementedError()

    def act(self, state, info):
        """
        This is the core of markowitz portfolio optimization
        it maximizes the éxpected_return - risk_aversion * risk
        with expected_return = mean_returns @ portfolio_weights
        and risk = portfolio_weights.T @ cov @ portfolio_weights
        The constraints say that the weights must be positive and sum to 1

        returns the action as the weights of the portfolio
        """
        # unpack state to get covariance and means
        data = info["data"].copy()
        # from the data estimate returns and covariances
        cov = data.iloc[-1].cov_list
        mean_returns = data[
            data["time"] == data["time"].max()
        ]["ewm_returns"].to_numpy()

        # solve markowitz model with cvxpy
        # initialize model
        num_stocks = len(mean_returns)
        weights = cp.Variable(num_stocks)
        risk_free_weight = cp.Variable(1)
        # define constraints
        # constraints = [cp.sum(weights) + risk_free_weight ==
        #                1, weights >= 0, risk_free_weight >= 0]
        constraints = [cp.sum(weights) == 1,
                       weights >= 0,
                    #    risk_free_weight >= 0
                       ]
        # define objective
        portfolio_return = mean_returns @ weights # + risk_free_weight*self.risk_free_rate
        portfolio_risk = cp.quad_form(weights, cov)
        # define objective
        objective = cp.Maximize(
            portfolio_return - self.risk_aversion * portfolio_risk)
        # define problem
        problem = cp.Problem(objective, constraints)
        # solve problem
        problem.solve()
        # get weights
        weights = weights.value
        # get action. if using risk free rate then integrate it into the action
        action = weights
        # action = np.concatenate([weights, risk_free_weight.value])
        action = np.maximum(action, 0)
        action = action / np.sum(action)
        return action

    def prediction(self, environment):
        # args = Arguments(env=environment)
        # args.if_off_policy
        # args.env = environment

        # test on the testing env
        state, info = environment.reset()
        day = environment.sorted_times[environment.time_index]
        history = defaultdict(list)

        total_asset = environment.portfolio_value
        history["date"].append(day)
        history["total_assets"].append(total_asset)
        history["episode_return"].append(0)
        # episode_total_assets.append(environment.initial_amount)
        done = False
        while not done:
            action = self.act(state, info)
            state, reward, done, trunc, info = environment.step(action)
            day = environment.sorted_times[environment.time_index]


            total_asset = environment.portfolio_value
            episode_return = total_asset / environment.initial_amount
            history["date"].append(day)
            history["total_assets"].append(total_asset)
            history["episode_return"].append(episode_return)
        print("Test Finished!")
        # return episode total_assets on testing data
        print("episode_return", episode_return)
        return pd.DataFrame(history)

# %%
# some hyperparameters for finrl
start_date=config.TRAIN_START_DATE
end_date=config.TRADE_END_DATE
ticker_list=config_tickers.DOW_30_TICKER
time_interval='1D'
data_source='yahoofinance'
technical_indicator_list= config.INDICATORS
if_vix=True
hmax=100
initial_amount=1000000
transaction_cost_pct=0.001
reward_scaling=1e-4
use_cached_model = False

# %% [markdown]
# # Download and process data

# %%
dp = DataProcessor(
    data_source=data_source,
    start_date=start_date,
    end_date=end_date,
    time_interval=time_interval,
)

price_array, tech_array, turbulence_array = dp.run(
    ticker_list, technical_indicator_list, if_vix=if_vix, cache=True, select_stockstats_talib=0
)

# add covariance matrix as states
df = dp.dataframe
df = df.sort_values(['time', 'tic'], ignore_index=True)
df.index = df.time.factorize()[0]

df["pct_change"] = df.groupby("tic").close.pct_change()

cov_list = []
# look back is one year
lookback = 252
for i in range(lookback, len(df.index.unique())):
    data_lookback = df.loc[i-lookback:i, :]
    price_lookback = data_lookback.pivot_table(
        index='time', columns='tic', values='close')
    return_lookback = price_lookback.pct_change().dropna()
    covs = return_lookback.cov().values
    cov_list.append(covs)
df["mean_pct_change_lookback"] = df.rolling(lookback)["pct_change"].mean()
df["ewm_returns"] = df["pct_change"].ewm(span=50).mean()
df_cov = pd.DataFrame(
    {'time': df.time.unique()[lookback:], 'cov_list': cov_list})
df = df.merge(df_cov, on='time')
df = df.sort_values(['time', 'tic']).reset_index(drop=True)
# Out:
# yahoofinance successfully connected
# Using cached file ./cache/AXP_AMGN_AAPL_BA_CAT_CSCO_CVX_GS_HD_HON_IBM_INTC_JNJ_KO_JPM_MCD_MMM_MRK_MSFT_NKE_PG_TRV_UNH_CRM_VZ_V_WBA_WMT_DIS_DOW_yahoofinance_2014-01-01_2021-12-01_1D.pickle
# tech_indicator_list:  ['macd', 'boll_ub', 'boll_lb', 'rsi_30', 'cci_30', 'dx_30', 'close_30_sma', 'close_60_sma']
# indicator:  macd
# indicator:  boll_ub
# indicator:  boll_lb
# indicator:  rsi_30
# indicator:  cci_30
# indicator:  dx_30
# indicator:  close_30_sma
# indicator:  close_60_sma
# Succesfully add technical indicators
# [*********************100%***********************]  1 of 1 completed
#            date       open       high        low      close  adjusted_close  \
# 0    2014-01-02  14.320000  14.590000  14.000000  14.230000       14.230000
# 1    2014-01-03  14.060000  14.220000  13.570000  13.760000       13.760000
# 2    2014-01-06  13.410000  14.000000  13.220000  13.550000       13.550000
# 3    2014-01-07  12.380000  13.280000  12.160000  12.920000       12.920000
# 4    2014-01-08  13.040000  13.240000  12.860000  12.870000       12.870000
# ...         ...        ...        ...        ...        ...             ...
# 1988 2021-11-23  20.240000  20.910000  19.030001  19.379999       19.379999
# 1989 2021-11-24  19.170000  20.959999  18.520000  18.580000       18.580000
# 1990 2021-11-26  26.620001  28.990000  23.879999  28.620001       28.620001
# 1991 2021-11-29  25.309999  25.690001  21.709999  22.959999       22.959999
# 1992 2021-11-30  26.230000  28.559999  23.709999  27.190001       27.190001
#
#       volume   tic  day
# 0          0  ^VIX    3
# 1          0  ^VIX    4
# 2          0  ^VIX    0
# 3          0  ^VIX    1
# 4          0  ^VIX    2
# ...      ...   ...  ...
# 1988       0  ^VIX    1
# 1989       0  ^VIX    2
# 1990       0  ^VIX    4
# 1991       0  ^VIX    0
# 1992       0  ^VIX    1
#
# [1993 rows x 9 columns]
# Shape of DataFrame:  (1993, 9)
# Download complete! Dataset saved to ./data/vix.csv.
# Shape of DataFrame: (1993, 9)
# Clean data for ^VIX
# /home/aaron/Research/finrl_experiments/FinRL-Meta/meta/data_processors/yahoofinance.py:177: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(tmp_df)
# Data clean for ^VIX is finished.
# Data clean all finished!
# Successfully transformed into array

# %% [markdown]
# # Run markowitz model on test data

# %%
test_df = data_split(
    df,
    start=config.TEST_START_DATE,
    end=config.TEST_END_DATE
)

stock_dimension = len(test_df.tic.unique())
state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")

env_kwargs = {
    "hmax": hmax,
    "initial_amount": initial_amount,
    "transaction_cost_pct": transaction_cost_pct,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": config.INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": reward_scaling
}
e_test_gym = StockPortfolioEnv(df=test_df, **env_kwargs)
agent = MarkowitzAgent(e_test_gym)
markowitz_history_df = agent.prediction(e_test_gym)
markowitz_history_df["method"] = "markowitz"
# Out:
# Stock Dimension: 30, State Space: 30
# =================================
# begin_total_asset:1000000
# end_total_asset:1317065.746292424
# Sharpe:  1.8108090198148892
# =================================
# Test Finished!
# episode_return 1.317065746292424

# %% [markdown]
# # Train RL model and evaluate on test data

# %%
train_df = data_split(df, start=config.TRAIN_START_DATE,
                        end=config.TRAIN_END_DATE)
stock_dimension = len(train_df.tic.unique())
state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")

env_kwargs = {
    "hmax": hmax,
    "initial_amount": initial_amount,
    "transaction_cost_pct": transaction_cost_pct,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": config.INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": reward_scaling
}
# use cached model if you are iterating on evaluation code
if use_cached_model and os.path.exists("saved_models/a2c_model.pt"):
    trained_a2c = A2C.load("saved_models/a2c_model.pt")
else:
    e_train_gym = StockPortfolioEnv(df=train_df, **env_kwargs)
    agent = DRLAgent(env=e_train_gym)

    A2C_PARAMS = {
        "n_steps": 10,
        "ent_coef": 0.005,
        "learning_rate": 0.0004
    }
    model_a2c = agent.get_model(model_name="a2c", model_kwargs=A2C_PARAMS)
    trained_a2c = agent.train_model(
        model=model_a2c,
        tb_log_name='a2c',
        total_timesteps=40000
        )
    # save trained_a2c model
    trained_a2c.save("saved_models/a2c_model.pt")

# evaluate on test data
test_df = data_split(
    df,
    start=config.TEST_START_DATE,
    end=config.TEST_END_DATE
)
e_test_gym = StockPortfolioEnv(df=test_df, **env_kwargs)

df_daily_return, df_actions = DRLAgent.DRL_prediction(
    model=trained_a2c,
    environment=e_test_gym,
)
df_daily_return["method"] = "a2c"
# Out:
# Stock Dimension: 30, State Space: 30
# {'n_steps': 10, 'ent_coef': 0.005, 'learning_rate': 0.0004}
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to tensorboard_log/a2c/a2c_5
# =================================
# begin_total_asset:1000000
# end_total_asset:1248417.1776510237
# Sharpe:  1.774486874366264
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1252205.0777428634
# Sharpe:  1.8009995898180302
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1310724.501821081
# Sharpe:  2.140183468539528
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1323749.164922317
# Sharpe:  2.1562175466180995
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1280735.6538467412
# Sharpe:  1.9666605233148007
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1279608.3690670228
# Sharpe:  1.9384561262521112
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1277645.2520812936
# Sharpe:  1.9393514169745476
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1300578.0002893917
# Sharpe:  2.047242121688753
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1286382.7150207304
# Sharpe:  1.9896934558931003
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1294842.3806843765
# Sharpe:  1.9946576049961435
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 202       |
# |    iterations         | 100       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 99        |
# |    policy_loss        | 2.79e+08  |
# |    reward             | 1258183.6 |
# |    std                | 0.996     |
# |    value_loss         | 6.1e+13   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1287306.7425610134
# Sharpe:  1.9873265873378763
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1319213.1939093638
# Sharpe:  2.142031224494262
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1273633.4083691922
# Sharpe:  1.9166856930949212
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1296426.6791865856
# Sharpe:  2.0165988508337502
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1285656.1338601122
# Sharpe:  1.9783821235682062
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1292069.88361073
# Sharpe:  2.013965400550129
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1277046.05846114
# Sharpe:  1.9170385447268343
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1261206.7675649251
# Sharpe:  1.8369315156399426
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1343720.072025603
# Sharpe:  2.270223574795473
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1283492.6016075038
# Sharpe:  1.9552776489892882
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1294526.3173552616
# Sharpe:  2.020873052856346
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.13e+08  |
# | time/                 |           |
# |    fps                | 201       |
# |    iterations         | 200       |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 199       |
# |    policy_loss        | 2.57e+08  |
# |    reward             | 1257135.0 |
# |    std                | 0.994     |
# |    value_loss         | 4.96e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1289401.4402391626
# Sharpe:  1.9650892949007852
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1329298.2510669606
# Sharpe:  2.173020499739016
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1303389.2605321785
# Sharpe:  2.0653042073392256
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1271134.7317635566
# Sharpe:  1.8882377731680111
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1301479.9132883933
# Sharpe:  2.078267265404861
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1292329.141646496
# Sharpe:  1.9855406180740403
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1305812.5959860145
# Sharpe:  2.0658247152130023
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1286119.7057066048
# Sharpe:  1.9632162473807726
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1287179.8829957393
# Sharpe:  1.9711393390223955
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1315448.6804408391
# Sharpe:  2.126269141047517
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1308235.5423900844
# Sharpe:  2.047638492142112
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 202       |
# |    iterations         | 300       |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 299       |
# |    policy_loss        | 2.44e+08  |
# |    reward             | 1158218.1 |
# |    std                | 0.994     |
# |    value_loss         | 4.36e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1281571.5634108968
# Sharpe:  1.9433276987943597
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1310763.615087021
# Sharpe:  2.0608047314252302
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1289410.1934329735
# Sharpe:  2.019082444565339
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1249624.163411505
# Sharpe:  1.7510625032457094
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1323378.0985408744
# Sharpe:  2.158545638618941
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1325782.9122027336
# Sharpe:  2.1718950737935447
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1299695.9573273773
# Sharpe:  2.029998116312385
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1287498.13528632
# Sharpe:  1.9598355204964573
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1267713.641670693
# Sharpe:  1.868875554678957
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1319100.2995866975
# Sharpe:  2.133155268567836
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1270874.827651288
# Sharpe:  1.880764376270588
# =================================
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 93       |
# |    ep_rew_mean        | 1.14e+08 |
# | time/                 |          |
# |    fps                | 201      |
# |    iterations         | 400      |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -42.4    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 399      |
# |    policy_loss        | 2.83e+08 |
# |    reward             | 956348.8 |
# |    std                | 0.993    |
# |    value_loss         | 5.91e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1301217.7856092118
# Sharpe:  2.036695712777582
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1307814.4442439023
# Sharpe:  2.094631003720335
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1304940.371656178
# Sharpe:  2.0644315418036454
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1307970.1326984798
# Sharpe:  2.099979429797044
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1269573.5480257203
# Sharpe:  1.8786390596754703
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1309153.9626425067
# Sharpe:  2.0682446886758123
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1259776.2701296678
# Sharpe:  1.8261524385042338
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1258630.1362168028
# Sharpe:  1.8354204067730333
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1278631.2645862144
# Sharpe:  1.9284072716334557
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1290366.8337807725
# Sharpe:  1.9854503853545966
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 203       |
# |    iterations         | 500       |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 499       |
# |    policy_loss        | 2.96e+08  |
# |    reward             | 1279333.9 |
# |    std                | 0.994     |
# |    value_loss         | 6.21e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1300105.1223124296
# Sharpe:  2.0514325107846023
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1296938.7554355233
# Sharpe:  2.0242964315456393
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1275100.0313838893
# Sharpe:  1.9217226505085503
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1295217.1220772672
# Sharpe:  2.0168439365292614
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1306090.7739628698
# Sharpe:  2.0940575211838026
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1303731.3355675128
# Sharpe:  2.0386188524982853
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1280186.398287291
# Sharpe:  1.9484324956364971
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1281942.3577234233
# Sharpe:  1.9639951892572016
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1251411.9491759997
# Sharpe:  1.7773387142735841
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1303777.514514696
# Sharpe:  2.0626994102306355
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1285579.0172360872
# Sharpe:  2.003771150297479
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 201       |
# |    iterations         | 600       |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 599       |
# |    policy_loss        | 2.76e+08  |
# |    reward             | 1246358.5 |
# |    std                | 0.995     |
# |    value_loss         | 4.94e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1262869.73958441
# Sharpe:  1.846414408393776
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1303267.2362207286
# Sharpe:  2.0799353523095565
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1271786.8496762102
# Sharpe:  1.9153576120624505
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1253622.2918574417
# Sharpe:  1.8010789162063743
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1302672.5344968096
# Sharpe:  2.069697866886628
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1285037.258059992
# Sharpe:  1.972306131227155
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1270535.631693436
# Sharpe:  1.8975672751484016
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1296783.6744057203
# Sharpe:  2.043795593855917
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1287195.4695143574
# Sharpe:  2.004338955503345
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1287536.4088266734
# Sharpe:  1.986403172787354
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1303073.5186184482
# Sharpe:  2.029825156187683
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 202       |
# |    iterations         | 700       |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 699       |
# |    policy_loss        | 2.64e+08  |
# |    reward             | 1157088.9 |
# |    std                | 0.994     |
# |    value_loss         | 4.32e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1264323.4103527877
# Sharpe:  1.8741667546599874
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1280548.1593756527
# Sharpe:  1.963204656770442
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1277123.2424829819
# Sharpe:  1.9216512518864424
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1296892.0423589568
# Sharpe:  2.069219893215755
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1331402.01574263
# Sharpe:  2.194129399661603
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1274022.1862170773
# Sharpe:  1.8784874029338607
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1289858.6506700385
# Sharpe:  2.0085203588964307
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1298276.012002997
# Sharpe:  2.0616142011937906
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1282316.4083629395
# Sharpe:  1.9685286301342675
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1309561.896911672
# Sharpe:  2.1320715625123077
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1302299.4838221138
# Sharpe:  2.059898002880881
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 202       |
# |    iterations         | 800       |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 799       |
# |    policy_loss        | 2.93e+08  |
# |    reward             | 928346.9  |
# |    std                | 0.993     |
# |    value_loss         | 6.19e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1279470.6911202671
# Sharpe:  1.9155920287146024
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1271803.0036868602
# Sharpe:  1.8909004697960698
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1293887.1795959754
# Sharpe:  2.022291763257186
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1279968.6067300763
# Sharpe:  1.930653070297677
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1299730.3804818525
# Sharpe:  2.0793006095386724
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1266511.1544484703
# Sharpe:  1.8859310139866277
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1275659.3689015252
# Sharpe:  1.9145163875125855
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1295187.1295125312
# Sharpe:  2.026723135884208
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1295093.3033454726
# Sharpe:  2.0464513813405216
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1307223.2113479553
# Sharpe:  2.086723210898661
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 202       |
# |    iterations         | 900       |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 899       |
# |    policy_loss        | 3.06e+08  |
# |    reward             | 1266249.2 |
# |    std                | 0.992     |
# |    value_loss         | 6.03e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1297324.8793972011
# Sharpe:  2.037411950228654
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1332321.955145035
# Sharpe:  2.2199090088476328
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1286607.024896714
# Sharpe:  1.9651478335755443
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1324751.4230085686
# Sharpe:  2.219511745587709
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1291088.3231914232
# Sharpe:  2.0158946367452213
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1299412.1695398483
# Sharpe:  2.045351556275636
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1288605.908627875
# Sharpe:  1.9898969854107276
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1251502.2960061324
# Sharpe:  1.771873708214534
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1306267.6560020922
# Sharpe:  2.0813382831928022
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1301146.5096796795
# Sharpe:  2.04562760413708
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1284802.3486705918
# Sharpe:  1.9775046148287192
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 202       |
# |    iterations         | 1000      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 999       |
# |    policy_loss        | 2.65e+08  |
# |    reward             | 1258421.1 |
# |    std                | 0.991     |
# |    value_loss         | 4.94e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1300289.8335519612
# Sharpe:  2.0466589621451385
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1287691.3468853207
# Sharpe:  1.97494085566539
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1280485.8695835245
# Sharpe:  1.9190041325723082
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1276453.3250116382
# Sharpe:  1.9087812405465137
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1280214.6601860793
# Sharpe:  1.9453662311938322
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1290261.7976655269
# Sharpe:  2.000628843365531
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1292270.6424779212
# Sharpe:  2.007904729831405
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1274972.7634259458
# Sharpe:  1.8918613738232803
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1271109.313701045
# Sharpe:  1.8883957565508631
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1297284.898826931
# Sharpe:  2.010775321593004
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1296761.3392085466
# Sharpe:  2.011083558804591
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 202       |
# |    iterations         | 1100      |
# |    time_elapsed       | 54        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1099      |
# |    policy_loss        | 2.65e+08  |
# |    reward             | 1203661.6 |
# |    std                | 0.99      |
# |    value_loss         | 4.64e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1296910.7077737006
# Sharpe:  2.022026499407602
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1283342.4154066863
# Sharpe:  1.9314531947878706
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1283253.316083205
# Sharpe:  1.9523145971141445
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1272598.054745455
# Sharpe:  1.8772886770580586
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1297876.4013105317
# Sharpe:  2.0436141366429097
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1275795.5662160213
# Sharpe:  1.9250102535124998
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1283558.115710258
# Sharpe:  1.9547809935596625
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1286686.187986628
# Sharpe:  1.958618765331332
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1297162.015880422
# Sharpe:  2.01230327593128
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1282785.7997313112
# Sharpe:  1.9612899764214866
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1269800.7056619723
# Sharpe:  1.8652366922101418
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 202       |
# |    iterations         | 1200      |
# |    time_elapsed       | 59        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -42.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1199      |
# |    policy_loss        | 3.13e+08  |
# |    reward             | 1037270.6 |
# |    std                | 0.988     |
# |    value_loss         | 6.06e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1304330.8052058055
# Sharpe:  2.0702710631647263
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1300023.3390748752
# Sharpe:  2.029214448623806
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1293578.5152172963
# Sharpe:  2.004228945049246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1300425.3698750988
# Sharpe:  2.0636118657179043
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1288525.4301584803
# Sharpe:  1.9741840418985368
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1284005.972525879
# Sharpe:  1.9593312917237582
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1288418.0339956712
# Sharpe:  2.003504860176066
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1283335.9584605016
# Sharpe:  1.930443041597823
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1289774.2585740923
# Sharpe:  1.9878433993832914
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1317865.0415613246
# Sharpe:  2.1090586293651676
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 202       |
# |    iterations         | 1300      |
# |    time_elapsed       | 64        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -42.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1299      |
# |    policy_loss        | 2.88e+08  |
# |    reward             | 1256982.6 |
# |    std                | 0.987     |
# |    value_loss         | 5.98e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1286094.8436096339
# Sharpe:  1.9517345626282878
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1277050.6750605737
# Sharpe:  1.9038710716125622
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1298519.7862709048
# Sharpe:  2.0411261239414737
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1286912.40193259
# Sharpe:  1.9759310127951992
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1278174.7335335892
# Sharpe:  1.9397455844698597
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1307668.0871816175
# Sharpe:  2.1036971330345717
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1284007.7471666122
# Sharpe:  1.9509188309984928
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1312364.293723595
# Sharpe:  2.082612555203067
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1295387.0695027895
# Sharpe:  1.9916699165276004
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1305326.6878764732
# Sharpe:  2.0540676933335877
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1311613.8509446145
# Sharpe:  2.092303706888424
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 202       |
# |    iterations         | 1400      |
# |    time_elapsed       | 69        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -42.2     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1399      |
# |    policy_loss        | 2.6e+08   |
# |    reward             | 1278452.4 |
# |    std                | 0.986     |
# |    value_loss         | 5.02e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1308134.6525610262
# Sharpe:  2.0622915092890017
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1288694.3970145627
# Sharpe:  1.9815876591901047
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1274718.06541457
# Sharpe:  1.8905786126063462
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1302999.168247715
# Sharpe:  2.068908449805643
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1287211.6485775139
# Sharpe:  1.9599625219542502
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1318102.029555186
# Sharpe:  2.1556351941571745
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1290929.011676243
# Sharpe:  1.979967994705965
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1306817.4520171785
# Sharpe:  2.055763407197912
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1289432.2276075247
# Sharpe:  1.9494931394913397
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1288983.785301512
# Sharpe:  1.9542972141994903
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1317716.8272025266
# Sharpe:  2.123398802236188
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 202       |
# |    iterations         | 1500      |
# |    time_elapsed       | 74        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -42.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1499      |
# |    policy_loss        | 2.59e+08  |
# |    reward             | 1218501.1 |
# |    std                | 0.986     |
# |    value_loss         | 4.75e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1314633.3450098215
# Sharpe:  2.1273842829577445
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1296988.2573162946
# Sharpe:  1.9996791985726856
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1296053.599452516
# Sharpe:  2.018018157551301
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1273696.9310462167
# Sharpe:  1.8931907477719647
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1304009.0419273751
# Sharpe:  2.038396111756074
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1286945.451874948
# Sharpe:  1.936453933778919
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1280250.9364763722
# Sharpe:  1.9225956789314553
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1283879.158575502
# Sharpe:  1.9480704407211071
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1275337.1486209522
# Sharpe:  1.9151471425297046
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1301725.705355759
# Sharpe:  2.052287579520067
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1288105.6027039287
# Sharpe:  2.0052543886915615
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 202       |
# |    iterations         | 1600      |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -42.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1599      |
# |    policy_loss        | 3.05e+08  |
# |    reward             | 1066750.1 |
# |    std                | 0.986     |
# |    value_loss         | 6.2e+13   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1313901.9139162723
# Sharpe:  2.1024045961155777
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1299094.0014318652
# Sharpe:  2.0207163446667633
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1274044.140775999
# Sharpe:  1.9034392339113444
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1299170.6849598656
# Sharpe:  2.0773129721898567
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1306067.3161371914
# Sharpe:  2.049075223081982
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1274851.8549513244
# Sharpe:  1.8919182535155363
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1291820.9490889625
# Sharpe:  1.9940350630974608
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1289966.7351775744
# Sharpe:  1.9938489700582724
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1307640.738905601
# Sharpe:  2.0762800664358743
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1309904.5211208803
# Sharpe:  2.0860835385768164
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 202       |
# |    iterations         | 1700      |
# |    time_elapsed       | 83        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -42.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1699      |
# |    policy_loss        | 2.92e+08  |
# |    reward             | 1299649.8 |
# |    std                | 0.984     |
# |    value_loss         | 6.02e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1279368.0695791862
# Sharpe:  1.948271962485094
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1291931.9853487522
# Sharpe:  2.0260730543496583
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1288881.8889219775
# Sharpe:  1.9995841678817556
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1293742.8332121007
# Sharpe:  2.0076320684056057
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1293548.075710806
# Sharpe:  1.995514192076554
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1284761.4201171119
# Sharpe:  1.9578162431947341
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1303777.389195661
# Sharpe:  2.054376718325921
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1294006.3821982325
# Sharpe:  1.9834766920004088
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1273095.8193238778
# Sharpe:  1.8889742377592886
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1317751.3706496167
# Sharpe:  2.1389457633445037
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1294572.618728211
# Sharpe:  2.0126813712901535
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 202       |
# |    iterations         | 1800      |
# |    time_elapsed       | 89        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1799      |
# |    policy_loss        | 2.72e+08  |
# |    reward             | 1285270.2 |
# |    std                | 0.983     |
# |    value_loss         | 5.03e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1288776.1643539849
# Sharpe:  1.9694653704219292
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1314358.4339232645
# Sharpe:  2.138604414963779
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1303050.0116676057
# Sharpe:  2.0671842861594003
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1281661.8221575676
# Sharpe:  1.9385092219499367
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1286946.5380325853
# Sharpe:  1.9819231421893226
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1297891.4277663284
# Sharpe:  2.0084096151122695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1290974.5843362808
# Sharpe:  1.9749264330988332
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1280156.7962568377
# Sharpe:  1.9194611611886876
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1262585.052130454
# Sharpe:  1.8189923125749874
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1304909.2779685664
# Sharpe:  2.0529411982921117
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1267381.7233130822
# Sharpe:  1.8533687523260574
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 202       |
# |    iterations         | 1900      |
# |    time_elapsed       | 94        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1899      |
# |    policy_loss        | 2.51e+08  |
# |    reward             | 1240756.5 |
# |    std                | 0.981     |
# |    value_loss         | 4.78e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1301961.7164878205
# Sharpe:  2.0702254617309555
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1311084.7362230127
# Sharpe:  2.1098884932289677
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1332105.7889224356
# Sharpe:  2.2043179574929725
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1275665.0771305463
# Sharpe:  1.9359961655323377
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1283051.6846517934
# Sharpe:  1.9512092822391154
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1249971.3252162114
# Sharpe:  1.7613686234153585
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1305888.972054962
# Sharpe:  2.086168719592119
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1303848.9765516724
# Sharpe:  2.0607493113473576
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1311627.8451092348
# Sharpe:  2.088231397746066
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1298417.6346684664
# Sharpe:  2.032398168299199
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1282215.077833193
# Sharpe:  1.9557077396738862
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 202       |
# |    iterations         | 2000      |
# |    time_elapsed       | 98        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -42       |
# ...
# =================================
# begin_total_asset:1000000
# end_total_asset:1291930.758300531
# Sharpe:  2.0423343556275064
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1321057.5617930966
# Sharpe:  2.2143193636011476
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1303234.8658665807
# Sharpe:  2.057434649326392
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1291730.7738994278
# Sharpe:  2.045065433447431
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 203       |
# |    iterations         | 3400      |
# |    time_elapsed       | 167       |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -41.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3399      |
# |    policy_loss        | 2.7e+08   |
# |    reward             | 1355490.4 |
# |    std                | 0.975     |
# |    value_loss         | 5.14e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1282473.711448595
# Sharpe:  1.986955747182592
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1290657.069122178
# Sharpe:  2.028967218217969
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1307127.6592641366
# Sharpe:  2.0992141614036077
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1312528.0969207191
# Sharpe:  2.1507812172483396
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1293883.7731833686
# Sharpe:  2.0483581354445675
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1281861.6912719838
# Sharpe:  1.9675212344557913
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1303992.3540586878
# Sharpe:  2.1078331858997874
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1298001.6815538246
# Sharpe:  2.05572134214717
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1299181.7740921953
# Sharpe:  2.067231290791826
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1298676.347567977
# Sharpe:  2.070133989112375
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1293783.4296016905
# Sharpe:  2.04009339468564
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 203       |
# |    iterations         | 3500      |
# |    time_elapsed       | 172       |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -41.8     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3499      |
# |    policy_loss        | 2.61e+08  |
# |    reward             | 1188292.4 |
# |    std                | 0.974     |
# |    value_loss         | 4.96e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1287389.0115217275
# Sharpe:  2.021961332298677
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1318345.6639241946
# Sharpe:  2.187945850629503
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1297680.8133880391
# Sharpe:  2.077935373149008
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1335192.6459156077
# Sharpe:  2.2632023467875677
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1296443.959252523
# Sharpe:  2.061457508254743
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1284780.5259640708
# Sharpe:  1.990296019990639
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1288286.2417020358
# Sharpe:  2.0095886475606437
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1277967.9590257208
# Sharpe:  1.9466616657601634
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1296830.0589498833
# Sharpe:  2.0690468187901203
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1299790.006539923
# Sharpe:  2.077320059178233
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1302452.6876981268
# Sharpe:  2.087028781867444
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 203       |
# |    iterations         | 3600      |
# |    time_elapsed       | 176       |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -41.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3599      |
# |    policy_loss        | 2.91e+08  |
# |    reward             | 1040900.1 |
# |    std                | 0.974     |
# |    value_loss         | 6.26e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1301348.5445927458
# Sharpe:  2.1031604821026404
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1292432.0903936338
# Sharpe:  2.042280584461102
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1314331.0715146232
# Sharpe:  2.142217275439901
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1296347.4438820225
# Sharpe:  2.0429713696176632
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1305665.1874084738
# Sharpe:  2.0887147268736315
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1298997.1701558
# Sharpe:  2.056912716891865
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1288940.8340747228
# Sharpe:  2.000413986530953
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1305355.1403917705
# Sharpe:  2.0769977973736906
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1307187.8523811274
# Sharpe:  2.122845157295717
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1317747.2895003215
# Sharpe:  2.1539042120263256
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 203       |
# |    iterations         | 3700      |
# |    time_elapsed       | 181       |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3699      |
# |    policy_loss        | 2.76e+08  |
# |    reward             | 1276745.1 |
# |    std                | 0.973     |
# |    value_loss         | 5.73e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1283652.2016307604
# Sharpe:  1.9783898769531547
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1328989.9843040225
# Sharpe:  2.2175603755127002
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1306919.2654449597
# Sharpe:  2.1010188509763728
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1310685.241326111
# Sharpe:  2.129309046560589
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1300253.7384199444
# Sharpe:  2.077653804158637
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1292890.0356265516
# Sharpe:  2.018918471248222
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1303851.9674003026
# Sharpe:  2.0737278459205313
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1285978.9735912734
# Sharpe:  1.990849454364867
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1322502.1125435093
# Sharpe:  2.18010664964122
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1319538.3991055575
# Sharpe:  2.183888734953392
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1297024.2818933288
# Sharpe:  2.047445981237987
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 203       |
# |    iterations         | 3800      |
# |    time_elapsed       | 186       |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3799      |
# |    policy_loss        | 2.93e+08  |
# |    reward             | 1351191.2 |
# |    std                | 0.972     |
# |    value_loss         | 5.31e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1304618.9394841876
# Sharpe:  2.1005134565527843
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1306951.0734061494
# Sharpe:  2.1094069482835107
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1299005.473873307
# Sharpe:  2.048403601914727
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1297053.0262761894
# Sharpe:  2.044283363742792
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1296535.862926814
# Sharpe:  2.059803303685706
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1295292.1960125277
# Sharpe:  2.026353508854622
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1305801.7423709258
# Sharpe:  2.098303587900814
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1277301.974912057
# Sharpe:  1.9545340435579093
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1311842.640527063
# Sharpe:  2.117585881680284
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1280728.3499185082
# Sharpe:  1.9635179397025257
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1308116.2859572147
# Sharpe:  2.117995502140141
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 203       |
# |    iterations         | 3900      |
# |    time_elapsed       | 191       |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3899      |
# |    policy_loss        | 2.71e+08  |
# |    reward             | 1185502.4 |
# |    std                | 0.971     |
# |    value_loss         | 5.06e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1299601.012142287
# Sharpe:  2.06739387094416
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1306361.443636447
# Sharpe:  2.0890556536856875
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1288266.2064652597
# Sharpe:  2.005492542441793
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1295906.2387993885
# Sharpe:  2.030000572553589
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1309154.942509866
# Sharpe:  2.1009385892756303
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1309247.241035208
# Sharpe:  2.103201931432398
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1288156.9972043752
# Sharpe:  2.000909550566551
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1316738.887595578
# Sharpe:  2.121646829293049
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1304245.0411410665
# Sharpe:  2.088277788613901
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1296076.525510503
# Sharpe:  2.0259728151394927
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1311297.7991322917
# Sharpe:  2.1104084561196714
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93        |
# |    ep_rew_mean        | 1.14e+08  |
# | time/                 |           |
# |    fps                | 203       |
# |    iterations         | 4000      |
# |    time_elapsed       | 196       |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3999      |
# |    policy_loss        | 2.89e+08  |
# |    reward             | 1085791.8 |
# |    std                | 0.971     |
# |    value_loss         | 6.32e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1315536.74562307
# Sharpe:  1.7236282900632034
# =================================
# hit end!

# %%
df_daily_return["total_assets"] = (1+df_daily_return["daily_return"]).cumprod() * e_test_gym.initial_amount

# %% [markdown]
# # Plot returns comparison

# %%
cols = ["date", "total_assets", "method"]
df_to_plot = pd.concat([df_daily_return[cols], markowitz_history_df[cols]])

sns.lineplot(
    x="date",
    y="total_assets",
    hue="method",
    data=df_to_plot
    )
plt.title("return comparison")
plt.show()

# %% [markdown]
# # Get returns tearsheet using pyfolio
# note that this requires a modified version of pyfolio which has bugs, ignore the download_data error as long as you get
# "yahoofinance successfully connected"

# %%
# code for analyzing returns using pyfolio, creating a tear sheet
import pyfolio as pf

# %%
try:
    _ = dp.processor.download_data(["^GSPC"], save_path="./data/sp500.csv")
except:
    pass
# Out:
# [*********************100%***********************]  1 of 1 completed
#            date         open         high          low        close  \
# 0    2014-01-02  1845.859985  1845.859985  1827.739990  1831.979980
# 1    2014-01-03  1833.209961  1838.239990  1829.130005  1831.369995
# 2    2014-01-06  1832.310059  1837.160034  1823.729980  1826.770020
# 3    2014-01-07  1828.709961  1840.099976  1828.709961  1837.880005
# 4    2014-01-08  1837.900024  1840.020020  1831.400024  1837.489990
# ...         ...          ...          ...          ...          ...
# 1988 2021-11-23  4678.479980  4699.390137  4652.660156  4690.700195
# 1989 2021-11-24  4675.779785  4702.870117  4659.890137  4701.459961
# 1990 2021-11-26  4664.629883  4664.629883  4585.430176  4594.620117
# 1991 2021-11-29  4628.750000  4672.950195  4625.259766  4655.270020
# 1992 2021-11-30  4640.250000  4646.020020  4560.000000  4567.000000
#
#       adjusted_close      volume    tic  day
# 0        1831.979980  3080600000  ^GSPC    3
# 1        1831.369995  2774270000  ^GSPC    4
# 2        1826.770020  3294850000  ^GSPC    0
# 3        1837.880005  3511750000  ^GSPC    1
# 4        1837.489990  3652140000  ^GSPC    2
# ...              ...         ...    ...  ...
# 1988     4690.700195  4277590000  ^GSPC    1
# 1989     4701.459961  3418430000  ^GSPC    2
# 1990     4594.620117  3517700000  ^GSPC    4
# 1991     4655.270020  4336410000  ^GSPC    0
# 1992     4567.000000  6625990000  ^GSPC    1
#
# [1993 rows x 9 columns]
# Shape of DataFrame:  (1993, 9)
# Download complete! Dataset saved to ./data/sp500.csv.
# Shape of DataFrame: (1993, 9)

# %%
sp500_data = pd.read_csv("./data/sp500.csv")

# %%
sp500_data = sp500_data.set_index(pd.to_datetime(sp500_data["date"]))
sp500_data.index = sp500_data.index.tz_localize('America/New_York')
sp500_data['pct_change'] = sp500_data.close.pct_change()
sp500_data = sp500_data.dropna()
# sp500_data.index = sp500_data.index.to_pydatetime()

# %% [markdown]
# # print quantstats metrics
# ideally we want to fix quantstats or compute the metrics ourselves, but this is just an example
#
# quantstats is broken for me requiring the try, catch

# %%
# quantstats tear sheet
for method_name in df_to_plot.method.unique():
    print(f"{method_name} tear sheet")
    port_returns = df_to_plot[df_to_plot["method"] == method_name].drop_duplicates("date").set_index("date")["total_assets"]
    port_returns.index = port_returns.index.tz_localize('America/New_York')

    try:
        pf.create_returns_tear_sheet(port_returns.pct_change().dropna(), benchmark_rets=sp500_data["pct_change"])
    except:
        pass
# Out:
# a2c tear sheet
# Entire data start date: 2020-08-04
# Entire data end date: 2021-09-30
# Backtest months: 13
# /home/aaron/miniconda3/envs/finrl/lib/python3.8/site-packages/pyfolio/timeseries.py:718: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   stats = pd.Series()
# /home/aaron/miniconda3/envs/finrl/lib/python3.8/site-packages/pyfolio/plotting.py:693: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for stat, value in perf_stats[column].iteritems():
#                     Backtest
# Annual return          26.6%
# Cumulative returns     31.6%
# Annual volatility      14.3%
# Sharpe ratio            1.73
# Calmar ratio            3.14
# Stability               0.90
# Max drawdown           -8.5%
# Omega ratio             1.33
# Sortino ratio           2.62
# Skew                   -0.04
# Kurtosis                1.59
# Tail ratio              1.10
# Daily value at risk    -1.7%
# Alpha                   0.04
# Beta                    0.84
# markowitz tear sheet
# Entire data start date: 2020-08-04
# Entire data end date: 2021-09-30
# Backtest months: 13
# /home/aaron/miniconda3/envs/finrl/lib/python3.8/site-packages/pyfolio/timeseries.py:718: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   stats = pd.Series()
# /home/aaron/miniconda3/envs/finrl/lib/python3.8/site-packages/pyfolio/plotting.py:693: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for stat, value in perf_stats[column].iteritems():
#                     Backtest
# Annual return          26.7%
# Cumulative returns     31.7%
# Annual volatility      13.6%
# Sharpe ratio            1.81
# Calmar ratio            4.62
# Stability               0.82
# Max drawdown           -5.8%
# Omega ratio             1.36
# Sortino ratio           2.93
# Skew                    0.54
# Kurtosis                3.09
# Tail ratio              1.17
# Daily value at risk    -1.6%
# Alpha                   0.11
# Beta                    0.58
